# %% [markdown]
# ###Makes a fake hairs file for the tenX reads where it partitions the variants based on their barcode.

# %%
# %run ./ipy_setup.py

# %%
def describe(obj):
    return obj, type(obj), len(obj)
pd.set_option('display.width', 900)
pd.set_option('display.max_columns', 100)
plt.style.use('ggplot')
rcParams['figure.figsize'] = (12, 8)
rcParams['figure.dpi'] = 150
rcParams['font.size'] = 16
rcParams['font.family'] = 'Bitstream Vera Sans'

# %% [markdown]
# # Barcode parser

# %%
# !samtools index /hpc/users/neffr01/jason_new/tenx/NIST_NA24385_possorted_bamout.fixed.sorted.000000F.bam

# %%
tenx_bam = pysam.AlignmentFile("/hpc/users/neffr01/jason_new/tenx/NIST_NA24385_possorted_bamout.fixed.sorted.000000F.bam", 'rb')

# %%
for read in tenx_bam.fetch():
    barcode = read.qname.split("_")[1].split('-')[0]
    print describe(barcode)
    break
# Out:
# ('TGCGTACACATCCA', <type 'str'>, 14)

# %%
excelfile = '/hpc/users/neffr01/jason_new/hapcut_outputs/hg002_re_000000F/hapcut_qv13_mq10/hg002.000000F.qv13mq10.redo.merged.iblockstats.tsv'
interblock_stats = pd.read_csv(excelfile, sep='\t')

# %%
for block in barcodes:
    for code in barcodes[block]:
        print code

# %%
barcodes = dict()
spans = zip(interblock_stats['block1_end'], interblock_stats['block2_start'])
pbar = ProgressBar(len(spans))
count = 1
for start, end in spans:
    #print start, end, end-start
    pbar.animate()
    barcodes[count] = dict()
    for read in tenx_bam.fetch(region="000000F", start=max(start-10000, 0), end=end+10000):
        barcode = read.qname.split("_")[1].split('-')[0]
        if barcode in barcodes[count]:
            barcodes[count][barcode]['pos'].append(int(read.pos))
            barcodes[count][barcode]['count'] += 1
        else:
            readdict = dict()
            readdict['pos'] = [int(read.pos)]
            readdict['count'] = 1            
            barcodes[count][barcode] = readdict
    count += 1
# Out:
# [*****************83%************      ]  242 of 292 complete Elapsed: 0.2 minutes	 Remaining: 0.0 minutes

# %%
hist = []
cutoff=30000
for block in barcodes:
    for barcode in barcodes[block]:
        hist.extend(list(np.diff(barcodes[block][barcode]['pos'])))
plt.hist(np.log10(hist), bins=np.linspace(0,5,40))
plt.axvline(np.log10(cutoff), 0, 400)
plt.show()
print (1-len([i for i in hist if i >= cutoff])/float(len(hist)))*100
# Out:
# 99.890612138

# %%
plt.hist([val['count'] for ix, val in barcodes[7].iteritems()], bins=range(0,140,2), log=True)
plt.show()

# %%
positions = barcodes[7]['AACGCTAGTATCGA']['pos']
plt.hist(positions, bins=range(min(positions), max(positions), 600))
plt.show()

# %%
for block in barcodes:
    for barcode in barcodes[block]:
        if barcodes[block][barcode] <= 10:
            continue # too few barcodes
        positions = barcodes[block][barcode]['pos']
        ranges = []
        startrange = positions[0]
        lastrange = positions[0]
        for ix,i in enumerate(positions[1:]):
            if startrange == None:
                startrange = i
                lastrange=i
                continue
            if i - lastrange > 30000:
                ranges.append((startrange, lastrange))
                startrange = None
            lastrange = i
        ranges.append((startrange, lastrange))
        barcodes[block][barcode]['ranges'] = ranges

# %%
count = 1
support_array = []
for start, end in spans:
    array = []
    support = 0
    for ix, val in barcodes[count].iteritems():
        array.append([val['count'], ix, val['ranges']])
    for cnt, barcode, ranges in array:
        if len([item for sublist in ranges for item in sublist]) > 2:
            for i in range(0,len(ranges)):
                if (ranges[i][0] <= start) & (ranges[i][1] >= end):
                    support += 1
        if len(ranges) > 0:
            if (ranges[0][0] <= start) & (ranges[0][1] >= end):
                support += 1
    support_array.append([count, start, end, end-start, support])
    count += 1

# %%
plt.scatter([i[3] for i in support_array], [i[4] for i in support_array])
plt.axhline(0,250000,0)
plt.xlim([0,250000])
plt.ylabel("Number of shared barcodes that can link blocks")
plt.xlabel('Length of interblock range')
plt.show()

# %%
def hamming_dist(str1, str2):
    difference = 0
    supp = 0
    for x,y in zip(str1, str2):
        if x != y:
            difference += 1
        if x == y:
            supp += 1
    return difference, supp

def get_refmap(bamread):
    bpos = bamread.get_aligned_pairs(matches_only=True)
    positions = [i[0] for i in bpos]
    refpos =  [i[1] for i in bpos] # positions in reference
    refmap = dict(zip(refpos, positions))
    return refmap

def get_matched_bases_in_read(bamread, in_pos, refmap):
    outseq = [bamread.seq[refmap[i]] if i in refmap else 'N' for i in in_pos]
    outseq = ''.join(outseq)
    outqual = [bamread.qual[refmap[i]] if i in refmap else 'N' for i in in_pos]
    outqual = ''.join(outqual)
    return outseq, outqual

def get_bases_between_two_ref_positions(bamread, pos1, pos2, refmap):
    outseq, outqual = '', ''
    refpos1, refpos2 = None, None
    positions = []
    for i in range(pos1,pos2+1):
        if (i not in refmap) and (refpos1 == None):
            outseq += 'N'
            outqual += '!'
            continue
        elif refpos1 == None:
            refpos1 = refmap[i]
        if i in refmap:
            refpos2 = refmap[i]
    try:
        outseq += ''.join([bamread.seq[i] for i in range(refpos1,refpos2)])
        outqual += ''.join([bamread.qual[i] for i in range(refpos1,refpos2)])
    except:
        pass
    return outseq, outqual

def reverse_compl(seq):
    translate = {'A':'T', 
                 'T':'A', 
                 'C':'G',
                 'G':'C'}
    return ''.join([translate[s] for s in seq])

# %%
a = [1,2,2,3,3,3,4,4,4]
atruth = [1 if i==2 else 0 for i in a]
# Out:
# [0, 1, 1, 0, 0, 0, 0, 0, 0]

# %%
# Okay, now let's link SNPs together on a  networkx multi-di-graph
import networkx as nx
from collections import defaultdict
from scipy.stats import mode

tenx_bam = pysam.AlignmentFile("/hpc/users/neffr01/jason_new/tenx/NIST_NA24385_possorted_bamout.fixed.sorted.000000F.bam", 'rb')
vcffile = ht.VCF_Reader("/hpc/users/neffr01/jason_new/hapcut_outputs/hg002_re_000000F/hg002_short_reads_rg-rmdup_000000F.freebayes.vcf")
vcffile.parse_meta()
vcffile.make_info_dict()
barcode_hairs = dict()
barcodegraph = nx.Graph()
lastreads = dict()
count = 0
pbar = ProgressBar(141000)
for var in vcffile:
    pbar.animate()
    count += 1
    vargeno = var.samples['hg002']['GT']
    if vargeno == '1/1' or vargeno == '0/0':
        continue
    varlen = len(var.ref)
    if varlen > 1:
        continue # TODO - this is complicated
    #print var, var.pos.pos, var.ref, var.alt, varlen, var.samples['unknown']['GT']
    if var.chrom != "000000F":
        break # we're done
    # lets add the node to the graph
    barcodegraph.add_node(var.chrom + ":" + str(var.pos.pos) + "_0", attr_dict={'description':str(var)})
    for i in range(0, len(var.alt)):
        i += 1
        barcodegraph.add_node(var.chrom + ":" + str(var.pos.pos) + "_" + str(i), attr_dict={'description':str(var)})
    barcodeset = defaultdict(list)
    for read in tenx_bam.fetch(region="000000F", start=var.pos.pos, end=var.pos.pos+len(var.ref)):
        barcode = read.qname.split("_")[1].split('-')[0]
        refmap = get_refmap(read)
        if read.mapq < 30:
            continue
        outseq, outqual = None, None
        #if varlen == 1:
        outseq, outqual = get_matched_bases_in_read(read, range(var.pos.pos-1, var.pos.pos+varlen-1), refmap)
        #else:
            #outseq, outqual = get_bases_between_two_ref_positions(read, var.pos.pos-1, var.pos.pos+varlen-1, refmap)
        if (outseq == ''):
            continue
        if (outseq[0] == 'N'):
            continue
        r, r_supp = hamming_dist(outseq, var.ref)
        a_diff = [hamming_dist(outseq, i)[0] for i in var.alt]
        a_supp = [hamming_dist(outseq, i)[1] for i in var.alt]
        genotype=None
        if r<min(a_diff):
            genotype=0
        elif min(a_diff)<r:
            atruth = [1 if i==min(a_diff) else 0 for i in a_diff]
            if sum(atruth) > 1:
                #print "WARNING: More than one match for alternate allele, skipping..."
                #print "read:", outseq, barcode, read.is_reverse, read.pos
                continue
            genotype=atruth.index(1)+1
        if genotype > 1:
            continue
        #else:
        #    if r_supp > max(a_supp):
        #        genotype=0
        #    elif max(a_supp) > r_supp:
        #        atruth = [1 if i==max(a_supp) else 0 for i in a_supp]
        #        if sum(atruth) > 1:
                    #print "WARNING: More than one match for alternate allele, skipping..."
                    #print "read:", outseq, barcode, read.is_reverse, read.pos
        #            continue
        #        genotype=atruth.index(1)+1
        #    else:
        #        #print "WARNING: No strong match to ref or alt sequence, skipping..."
        #        #print "read:", outseq, barcode, read.is_reverse, read.pos
        #        continue
        #print outseq, outqual, genotype, barcode, read.is_reverse, read.pos
        # now lets add the read edges
        barcodeset[barcode].append(genotype)
    for i,val in barcodeset.iteritems():
        most_likely_geno = int(mode(val)[0][0])
        geno_support = int(mode(val)[1][0])
        nodename = var.chrom + ":" + str(var.pos.pos) + "_" + str(most_likely_geno)
        line = (count,most_likely_geno,geno_support)
        if i in lastreads:
            num_edges = geno_support + lastreads[i][1]
            a = lastreads[i][0]
            b  = nodename
            if int(b.split(":")[1].split("_")[0]) < int(a.split(":")[1].split("_")[0]) + 1000000:
                # add to barcode in hairs file
                barcode_hairs[i][-1].append(line)
            else:
                # create new barcode block in hairs file and add to it
                barcode_hairs[i].append([line])
        else:
            barcode_hairs[i] = [[line]]
        lastreads[i] = (nodename, geno_support)
    #break
    #print barcodeset
    #if count > 1000:
    #    break
# Out:
# [****************100%******************]  141329 of 141000 complete Elapsed: 1.4 minutes	 Remaining: -0.0 minutes

# %%
barcode_hairs2 = barcode_hairs.copy()

# %%
barcode_hairs
# Out:
# {'TACCTTGTTTACTA': [[(69702, 1, 1), (69703, 1, 1)]],
#  'GAATCCAGTCTGAA': [[(106355, 1, 1)]],
#  'GATACCAGGACATT': [[(67678, 1, 1)]],
#  'CACAGTCACCTTGA': [[(117419, 0, 1)]],
#  'CTATGGCATCGTTG': [[(90901, 1, 1),
#    (90951, 2, 3),
#    (90952, 1, 1),
#    (90953, 1, 2)]],
#  'ACGAGGTCTTGGCA': [[(38855, 1, 2)], [(107563, 0, 1), (107564, 0, 1)]],
#  'CAAAGATCACCCTC': [[(31894, 2, 1), (31896, 1, 1), (31929, 1, 1)]],
#  'GGCATTAGTAGAAA': [[(107819, 1, 1)]],
#  'GATTCGCAAAGTTG': [[(123064, 0, 1)]],
#  'GCCATACAGGCTTT': [[(109775, 1, 1), (109798, 1, 1), (109802, 1, 1)],
#   [(110126, 1, 1), (110146, 1, 1), (110154, 1, 1)],
#   [(110505, 1, 1), (110507, 1, 1)],
#   [(110666, 0, 1),
#    (110732, 1, 1),
#    (110734, 0, 2),
#    (110735, 1, 1),
#    (110806, 1, 1),
#    (110850, 1, 1),
#    (110851, 0, 1)],
#   [(111161, 1, 1)],
#   [(124226, 1, 1)]],
#  'CGGGAATCCTAGCA': [[(104167, 1, 1)],
#   [(108234, 1, 1), (108259, 1, 1)],
#   [(108388, 1, 3), (108440, 0, 2)]],
#  'GGGTAGAGTATCAG': [[(112698, 0, 2), (112699, 0, 1)]],
#  'TGAGAACACTGGTT': [[(82693, 1, 2),
#    (82761, 1, 1),
#    (82762, 1, 2),
#    (82775, 1, 1),
#    (82785, 1, 2),
#    (82843, 1, 2),
#    (82855, 0, 1),
#    (82864, 1, 1),
#    (82865, 1, 1),
#    (82970, 1, 1),
#    (83028, 1, 1),
#    (83061, 1, 2),
#    (83066, 1, 1),
#    (83085, 1, 1),
#    (83105, 1, 2),
#    (83107, 1, 3),
#    (83109, 1, 3),
#    (83116, 0, 1),
#    (83118, 1, 2),
#    (83125, 1, 2),
#    (83129, 1, 1),
#    (83130, 1, 1)],
#   [(100880, 1, 1)]],
#  'GTTACGCATTCACG': [[(34864, 1, 1),
#    (34865, 1, 1),
#    (34866, 1, 1),
#    (34867, 1, 1)]],
#  'TGGTACTCATACTA': [[(60077, 1, 2)]],
#  'ATCCAGGTAGCTTC': [[(46384, 1, 2), (46385, 1, 2)], [(79123, 1, 1)]],
#  'GTTGCATCACCGAT': [[(112193, 1, 1),
#    (112261, 1, 1),
#    (112274, 1, 1),
#    (112275, 1, 1),
#    (112276, 1, 1),
#    (112280, 2, 1),
#    (112340, 1, 1)]],
#  'GCTTGAAGAAAGTA': [[(86790, 0, 1),
#    (86812, 2, 1),
#    (86834, 1, 1),
#    (86850, 1, 1),
#    (86859, 1, 2),
#    (86993, 1, 1),
#    (87073, 1, 1)]],
#  'TGCTAGGTTTCAAT': [[(37030, 1, 1), (37034, 1, 1)]],
#  'TGCGTATCTTCGGA': [[(13368, 0, 1)],
#   [(123476, 1, 1), (123477, 1, 1), (123478, 1, 1), (123479, 1, 1)]],
#  'CATTGGAGTACAAC': [[(98201, 1, 1)]],
#  'TCTATCGTTGTCAC': [[(40444, 1, 2),
#    (40448, 0, 1),
#    (40449, 1, 4),
#    (40452, 1, 2)]],
#  'ACGGTTTCAGACTC': [[(3943, 1, 1)],
#   [(24622, 1, 1),
#    (24624, 1, 1),
#    (24637, 1, 1),
#    (24644, 1, 1),
#    (24651, 1, 1),
#    (24681, 1, 2),
#    (24691, 0, 2),
#    (24698, 1, 1)],
#   [(24901, 1, 1)],
#   [(49757, 0, 1),
#    (49763, 0, 1),
#    (49766, 1, 1),
#    (49767, 0, 1),
#    (49770, 0, 5),
#    (49772, 0, 2),
#    (49773, 0, 2),
#    (49774, 1, 1),
#    (49776, 0, 4),
#    (49777, 0, 6),
#    (49782, 1, 2),
#    (49784, 0, 1),
#    (49792, 0, 2),
#    (49802, 2, 3),
#    (49810, 0, 2),
#    (49814, 0, 1),
#    (49815, 0, 1),
#    (49819, 1, 1),
#    (49820, 2, 2),
#    (49827, 0, 1),
#    (49829, 2, 3),
#    (49838, 2, 1),
#    (49849, 0, 1),
#    (49851, 1, 1),
#    (49853, 1, 1),
#    (49856, 2, 5),
#    (49867, 1, 1),
#    (49868, 2, 2),
#    (49871, 2, 1),
#    (49885, 1, 1),
#    (49893, 1, 2),
#    (49897, 1, 1),
#    (49906, 0, 2),
#    (49910, 1, 1),
#    (49913, 1, 1),
#    (49944, 1, 1),
#    (49948, 0, 1),
#    (49950, 1, 2),
#    (49956, 1, 1),
#    (49958, 0, 1),
#    (49962, 1, 1),
#    (49963, 1, 1),
#    (49966, 1, 1),
#    (49967, 1, 1),
#    (49972, 1, 1),
#    (49973, 1, 1),
#    (49981, 0, 1),
#    (49982, 0, 1),
#    (49983, 0, 4),
#    (49984, 0, 1),
#    (49988, 2, 2),
#    (49991, 0, 1),
#    (49992, 0, 1),
#    (49995, 1, 1),
#    (50020, 0, 1),
#    (50036, 0, 1),
#    (50047, 1, 2),
#    (50049, 0, 1),
#    (50050, 2, 1),
#    (50060, 0, 3),
#    (50066, 1, 1),
#    (50069, 0, 2),
#    (50086, 1, 2),
#    (50089, 1, 2),
#    (50090, 1, 1),
#    (50094, 1, 1),
#    (50095, 2, 1),
#    (50096, 1, 2),
#    (50099, 1, 1),
#    (50102, 0, 1),
#    (50109, 2, 1),
#    (50110, 2, 3),
#    (50111, 2, 2),
#    (50112, 1, 1),
#    (50114, 1, 3),
#    (50115, 2, 3),
#    (50116, 2, 2),
#    (50117, 1, 1),
#    (50118, 1, 1),
#    (50122, 0, 1),
#    (50123, 0, 1),
#    (50128, 1, 1),
#    (50129, 1, 1),
#    (50130, 1, 1),
#    (50148, 1, 1),
#    (50150, 0, 1),
#    (50156, 1, 1),
#    (50186, 1, 2),
#    (50187, 1, 3),
#    (50188, 1, 1),
#    (50190, 2, 1),
#    (50192, 0, 2),
#    (50195, 1, 2),
#    (50198, 1, 1),
#    (50203, 2, 1),
#    (50208, 2, 1),
#    (50214, 0, 2),
#    (50216, 0, 1),
#    (50217, 0, 1),
#    (50234, 0, 1)],
#   [(50246, 0, 2), (50252, 0, 1)]],
#  'GGATTCGTCTTCCC': [[(120095, 1, 1),
#    (120096, 0, 1),
#    (120098, 1, 3),
#    (120099, 1, 1)]],
#  'CCAGTACAACGGGT': [[(104350, 1, 1)], [(111017, 2, 1)]],
#  'CTCGTCGTCTCAGT': [[(90133, 1, 2)]],
#  'GAAGTAAGCACGGT': [[(19394, 1, 1)],
#   [(21898, 0, 1)],
#   [(56706, 0, 1), (56716, 1, 1)],
#   [(113760, 0, 1)]],
#  'TGTGACTCTGACCA': [[(29065, 1, 1), (29083, 1, 1), (29092, 0, 1)],
#   [(29165, 1, 1),
#    (29186, 1, 1),
#    (29191, 1, 1),
#    (29200, 1, 1),
#    (29212, 1, 3),
#    (29213, 1, 1),
#    (29225, 1, 1),
#    (29271, 0, 1),
#    (29413, 1, 1),
#    (29424, 1, 1),
#    (29425, 1, 3),
#    (29426, 1, 2)],
#   [(29746, 1, 1),
#    (29748, 1, 1),
#    (29761, 1, 1),
#    (29767, 1, 4),
#    (29768, 1, 3),
#    (29769, 1, 3),
#    (29771, 1, 3),
#    (29779, 1, 1),
#    (29807, 1, 1),
#    (29810, 1, 1),
#    (29814, 1, 1),
#    (29831, 1, 1)],
#   [(85923, 1, 1), (85938, 0, 1), (85940, 0, 1), (85941, 0, 1)]],
#  'AGACAAGTCTTCAG': [[(61280, 0, 1)]],
#  'TCCCGTGTAAACGT': [[(10459, 1, 1)]],
#  'AGATCCCAGAATGT': [[(76786, 1, 1), (76787, 0, 5)]],
#  'TGTTGGTCTGTTCT': [[(30805, 1, 2),
#    (30817, 0, 1),
#    (30820, 0, 2),
#    (30821, 2, 1),
#    (30832, 1, 2),
#    (30855, 1, 2),
#    (30859, 1, 1),
#    (30863, 1, 1),
#    (30864, 1, 2),
#    (30866, 1, 1),
#    (30868, 1, 1),
#    (30869, 1, 1),
#    (30877, 1, 3),
#    (30878, 1, 1),
#    (30881, 0, 2),
#    (30882, 1, 2),
#    (30883, 1, 2)],
#   [(119012, 0, 1), (119103, 0, 1)]],
#  'CCTTATAGCCAGGT': [[(92900, 1, 3)]],
#  'TGTAGCTCCGAATC': [[(123758, 1, 1),
#    (123759, 1, 1),
#    (123760, 1, 1),
#    (123761, 0, 1),
#    (123888, 1, 1),
#    (123998, 1, 1),
#    (124020, 1, 1),
#    (124021, 1, 2),
#    (124022, 1, 1),
#    (124089, 1, 1),
#    (124100, 1, 2),
#    (124118, 0, 1),
#    (124121, 0, 2),
#    (124143, 1, 1),
#    (124154, 0, 1),
#    (124156, 1, 4)],
#   [(124290, 0, 1), (124304, 1, 1), (124320, 1, 1), (124332, 0, 2)]],
#  'TGCTAGAGGCCATG': [[(61066, 0, 1), (61067, 0, 1)], [(102643, 1, 1)]],
#  'AGAAACCATTCACG': [[(48581, 1, 1), (48584, 0, 1)],
#   [(67002, 0, 1)],
#   [(114787, 1, 2)]],
#  'AGCAAATCCGGTAT': [[(45302, 1, 2)]],
#  'TCCGTCTCCGAATC': [[(58594, 1, 1), (58596, 1, 1)], [(74659, 0, 1)]],
#  'GGAGTGAGGTGTGC': [[(104314, 0, 1),
#    (104315, 1, 1),
#    (104321, 1, 3),
#    (104368, 1, 1)]],
#  'TGGTCAAGGCATTA': [[(115912, 1, 1)]],
#  'ATGGCTCAGTATAG': [[(74313, 1, 1)],
#   [(74552, 1, 1), (74582, 1, 1), (74590, 1, 2), (74698, 1, 1)],
#   [(74863, 1, 1), (74921, 1, 1)]],
#  'CTGCTCGTTAAGCA': [[(64447, 0, 1), (64451, 0, 2), (64454, 0, 1)]],
#  'GACGGATCTGGAAA': [[(116106, 1, 1)]],
#  'AGTCGTCACGGTTT': [[(103225, 0, 3)]],
#  'GTGGAGCACCGTGC': [[(9220, 1, 1)],
#   [(59437, 1, 1), (59462, 1, 1), (59499, 1, 1)],
#   [(59634, 0, 1)],
#   [(59745, 1, 1), (59757, 1, 1), (59773, 1, 1), (59826, 1, 1), (59915, 1, 1)],
#   [(60026, 1, 1),
#    (60031, 0, 1),
#    (60032, 0, 1),
#    (60039, 0, 1),
#    (60043, 1, 1),
#    (60050, 1, 1),
#    (60079, 1, 1),
#    (60152, 1, 1),
#    (60164, 1, 2)]],
#  'CCGATACACCTAGT': [[(51846, 0, 1)]],
#  'GCCAATCATACGTC': [[(67957, 1, 1),
#    (67962, 1, 1),
#    (67976, 1, 2),
#    (67980, 0, 1),
#    (67981, 1, 1),
#    (67989, 0, 1),
#    (67990, 0, 1),
#    (67991, 1, 2),
#    (67994, 2, 1),
#    (68000, 0, 1),
#    (68006, 1, 2),
#    (68007, 1, 1),
#    (68008, 1, 2),
#    (68009, 1, 1)],
#   [(68491, 0, 1), (68494, 1, 1)]],
#  'CGAGAGTCATTCCT': [[(87880, 1, 1), (87881, 1, 1)]],
#  'GTAAGACATCGCTA': [[(87262, 1, 2)]],
#  'AACTGCAGTTCGTC': [[(6336, 0, 1)],
#   [(84884, 2, 1),
#    (84898, 1, 1),
#    (84905, 1, 3),
#    (84924, 0, 3),
#    (84934, 0, 3),
#    (84944, 1, 1),
#    (84959, 0, 3),
#    (84960, 0, 3),
#    (84973, 1, 1),
#    (84975, 1, 1),
#    (84980, 1, 1),
#    (84981, 1, 5),
#    (84982, 1, 3),
#    (84983, 1, 1),
#    (84984, 1, 1),
#    (84993, 1, 3),
#    (84996, 1, 1)],
#   [(102709, 0, 1)]],
#  'ACGGGAGTTACTTA': [[(57669, 1, 1)], [(61060, 0, 1)]],
#  'CGTAACGTTGATAG': [[(87600, 0, 2)],
#   [(121003, 1, 1),
#    (121005, 1, 1),
#    (121006, 0, 1),
#    (121010, 1, 1),
#    (121014, 1, 1),
#    (121035, 0, 1)]],
#  'GCTTCCGTAATCCC': [[(63197, 0, 1)], [(78482, 0, 1)]],
#  'TGCCTCCATACTCG': [[(35363, 1, 2)]],
#  'CCTGAACACCTTGA': [[(67493, 1, 2)], [(75717, 0, 1)]],
#  'ATTGGCTCTGCTTT': [[(13606, 1, 1)],
#   [(19948, 0, 1)],
#   [(49972, 0, 1), (50076, 2, 1), (50120, 2, 1)],
#   [(56292, 1, 1)]],
#  'GAGGGTAGGCTGTG': [[(95685, 1, 1)]],
#  'TTGCCCGTGACTAA': [[(61060, 0, 1)], [(123064, 0, 1)]],
#  'TCTCTACAGATCAA': [[(69155, 0, 1)]],
#  'ACCAGTGTTGTACC': [[(66714, 1, 1)]],
#  'GGAGGTGTTGGTTC': [[(81350, 1, 1)], [(102647, 0, 1)]],
#  'CTGAGTCATCCTAG': [[(46384, 1, 1), (46385, 0, 1)]],
#  'TAAGAGTCTGCTTT': [[(88545, 1, 1)]],
#  'TCGACAAGTTGCTC': [[(85229, 1, 5), (85231, 1, 4), (85233, 1, 2)]],
#  'CAAGGGCACGCATT': [[(9324, 0, 1)]],
#  'TGCACATCCGCGGT': [[(4573, 0, 1), (4574, 0, 2), (4575, 0, 3)],
#   [(66406, 0, 1)]],
#  'CGATTGAGTTCGGG': [[(72025, 1, 1)], [(83661, 1, 1)], [(93993, 1, 1)]],
#  'GGTTCAAGTGAGCC': [[(25765, 1, 1)],
#   [(42487, 2, 1)],
#   [(66092, 0, 1)],
#   [(78482, 0, 1)],
#   [(107016, 1, 1)],
#   [(107212, 1, 1),
#    (107216, 1, 1),
#    (107217, 1, 1),
#    (107218, 1, 3),
#    (107219, 1, 1),
#    (107248, 0, 2),
#    (107251, 1, 1),
#    (107252, 2, 1),
#    (107253, 2, 1)]],
#  'AGTGAACAATTGAG': [[(51414, 2, 1),
#    (51434, 1, 1),
#    (51436, 1, 1),
#    (51445, 1, 1),
#    (51456, 0, 1),
#    (51484, 1, 1),
#    (51485, 1, 1),
#    (51501, 1, 1)],
#   [(110197, 1, 3),
#    (110199, 2, 1),
#    (110202, 2, 1),
#    (110203, 2, 1),
#    (110206, 1, 1),
#    (110207, 2, 2),
#    (110213, 1, 1),
#    (110219, 2, 2),
#    (110222, 1, 1),
#    (110225, 0, 1),
#    (110228, 1, 1),
#    (110231, 1, 1),
#    (110247, 0, 3),
#    (110254, 1, 2),
#    (110267, 2, 1),
#    (110273, 1, 2),
#    (110284, 1, 2),
#    (110305, 0, 1)]],
#  'ACTTTCAGTGCGCA': [[(21362, 0, 2)],
#   [(29752, 1, 1)],
#   [(45551, 1, 1)],
#   [(45748, 0, 2), (45792, 0, 2)],
#   [(92554, 1, 1)],
#   [(106355, 0, 1)],
#   [(115430, 1, 1)]],
#  'ATTCGGGTTTATTG': [[(100953, 1, 1)]],
#  'GTCAACGTTACATT': [[(96613, 1, 1),
#    (96619, 1, 1),
#    (96634, 0, 2),
#    (96636, 2, 2),
#    (96645, 0, 1),
#    (96649, 1, 2),
#    (96651, 1, 1),
#    (96655, 2, 1),
#    (96656, 1, 1),
#    (96657, 1, 2),
#    (96658, 1, 1),
#    (96659, 1, 3),
#    (96660, 1, 2),
#    (96665, 0, 2),
#    (96669, 1, 1),
#    (96670, 1, 1),
#    (96676, 1, 1),
#    (96691, 1, 1),
#    (96694, 1, 1),
#    (96699, 1, 1),
#    (96701, 1, 1),
#    (96713, 2, 2),
#    (96733, 0, 1),
#    (96736, 0, 1),
#    (96747, 2, 1),
#    (96805, 1, 1),
#    (96812, 2, 1),
#    (96829, 1, 1),
#    (96830, 1, 1),
#    (96846, 1, 1),
#    (96847, 1, 1),
#    (96859, 2, 1),
#    (96866, 1, 1),
#    (96873, 1, 1),
#    (96880, 2, 1),
#    (96881, 1, 1),
#    (96890, 1, 1),
#    (96891, 1, 1),
#    (96901, 0, 1),
#    (96907, 0, 1),
#    (96961, 1, 2),
#    (96978, 1, 2),
#    (96983, 0, 1),
#    (97004, 0, 1),
#    (97005, 1, 1),
#    (97023, 1, 1),
#    (97031, 1, 3),
#    (97070, 1, 2),
#    (97071, 0, 1),
#    (97075, 0, 1),
#    (97077, 0, 1),
#    (97087, 0, 3),
#    (97093, 0, 2),
#    (97094, 1, 2),
#    (97096, 0, 2),
#    (97104, 1, 1),
#    (97105, 2, 1),
#    (97106, 1, 1),
#    (97107, 1, 1),
#    (97110, 1, 1),
#    (97116, 1, 3),
#    (97119, 1, 1),
#    (97126, 1, 1),
#    (97138, 2, 1),
#    (97151, 2, 1),
#    (97158, 0, 1),
#    (97159, 1, 2),
#    (97162, 2, 1),
#    (97163, 2, 1),
#    (97170, 2, 1),
#    (97172, 1, 2),
#    (97192, 1, 1),
#    (97207, 0, 1),
#    (97227, 1, 1),
#    (97261, 1, 1),
#    (97270, 1, 2),
#    (97285, 1, 1),
#    (97297, 1, 1),
#    (97311, 1, 1),
#    (97389, 1, 1),
#    (97438, 1, 1),
#    (97444, 1, 1),
#    (97445, 0, 1),
#    (97449, 1, 1),
#    (97452, 1, 1),
#    (97469, 2, 2),
#    (97475, 1, 1),
#    (97479, 1, 1),
#    (97490, 1, 2),
#    (97491, 1, 1),
#    (97513, 2, 2),
#    (97526, 1, 1),
#    (97538, 1, 1),
#    (97540, 1, 4),
#    (97543, 1, 3),
#    (97550, 1, 3),
#    (97561, 1, 1),
#    (97563, 1, 1),
#    (97575, 1, 1),
#    (97584, 1, 1),
#    (97594, 0, 1),
#    (97609, 1, 1)],
#   [(106053, 0, 1)]],
#  'CAGCATGTATCTTA': [[(34848, 0, 1),
#    (34849, 0, 1),
#    (34850, 0, 1),
#    (34851, 0, 1),
#    (34852, 0, 1),
#    (34853, 0, 2),
#    (34854, 0, 1),
#    (34855, 0, 1),
#    (34856, 0, 1),
#    (34861, 0, 1),
#    (34863, 1, 2),
#    (34864, 0, 2),
#    (34865, 0, 2),
#    (34866, 0, 3),
#    (34867, 0, 3),
#    (34868, 0, 1),
#    (34873, 0, 1)],
#   [(84141, 0, 1)],
#   [(117213, 0, 1)]],
#  'GAAATGAGCGCCCT': [[(74380, 0, 2),
#    (74384, 1, 3),
#    (74394, 1, 1),
#    (74398, 1, 2),
#    (74429, 1, 1),
#    (74430, 1, 2),
#    (74432, 1, 2)]],
#  'GCAGTTGTACTACC': [[(68568, 1, 1)]],
#  'TGACCATCAAAGTG': [[(60272, 1, 1)]],
#  'TCGAACTCCTCATT': [[(4593, 1, 1)],
#   [(4665, 0, 1),
#    (4677, 1, 1),
#    (4699, 2, 2),
#    (4716, 0, 1),
#    (4752, 1, 1),
#    (4758, 1, 1),
#    (4760, 1, 1),
#    (4761, 0, 2),
#    (4766, 1, 1),
#    (4799, 1, 1),
#    (4804, 0, 1),
#    (4806, 0, 2),
#    (4811, 2, 1),
#    (4813, 1, 1),
#    (4823, 2, 1),
#    (4824, 2, 1),
#    (4836, 1, 2),
#    (4837, 1, 2),
#    (4880, 1, 2),
#    (4883, 0, 1),
#    (4919, 1, 2),
#    (4969, 0, 1),
#    (4972, 0, 2),
#    (4984, 0, 2)],
#   [(123064, 0, 1)]],
#  'TCAGCACAGGAATT': [[(118106, 1, 1), (118120, 0, 1)]],
#  'CAAGAAGTGTTAAG': [[(28378, 1, 1),
#    (28379, 1, 1),
#    (28414, 2, 1),
#    (28492, 0, 1),
#    (28499, 1, 1),
#    (28518, 1, 1),
#    (28519, 1, 2),
#    (28526, 1, 3),
#    (28563, 1, 1),
#    (28564, 0, 2)]],
#  'TGTGTGAGCCGTAG': [[(25340, 1, 1)]],
#  'GCATACAGGCGACT': [[(107805, 0, 1)]],
#  'TGCACATCGTTCCC': [[(69166, 0, 1)]],
#  'ATCGACCATAGTAG': [[(118893, 1, 1), (118894, 1, 1), (118898, 1, 1)]],
#  'GGATAAAGAGAGTG': [[(98690, 2, 1), (98692, 1, 1)]],
#  'TGAAGATCTTTGAA': [[(17455, 0, 1)],
#   [(68483, 1, 1)],
#   [(79605, 0, 2), (79606, 0, 5), (79607, 1, 1)]],
#  'CTGACACATATCAT': [[(110916, 0, 1)]],
#  'TCCTTAGTACTCGT': [[(6103, 0, 1), (6104, 0, 1)]],
#  'CAGACTCAATGTTT': [[(21405, 0, 1), (21406, 0, 1)],
#   [(56535, 1, 1), (56536, 1, 2), (56555, 1, 1)]],
#  'AGTGGGTCTGGACT': [[(110016, 0, 1)],
#   [(123580, 0, 1)],
#   [(123655, 1, 1), (123656, 0, 1), (123657, 1, 1)]],
#  'AGGTTCGTCATACC': [[(106355, 0, 1)]],
#  'GGATTCGTCTCCGG': [[(23976, 0, 1), (23978, 1, 1)]],
#  'AGCGAGAGCTTAGA': [[(482, 1, 1),
#    (486, 2, 2),
#    (490, 1, 2),
#    (492, 0, 1),
#    (508, 1, 1),
#    (511, 1, 5),
#    (518, 2, 2),
#    (521, 0, 2),
#    (523, 1, 2),
#    (525, 1, 2),
#    (542, 0, 1),
#    (544, 0, 1),
#    (548, 0, 1),
#    (549, 1, 1),
#    (550, 1, 1),
#    (566, 0, 1),
#    (575, 0, 1),
#    (580, 0, 2),
#    (586, 1, 1),
#    (591, 1, 1),
#    (600, 2, 1),
#    (624, 0, 1),
#    (661, 1, 2),
#    (662, 0, 1),
#    (663, 0, 3),
#    (664, 1, 2),
#    (694, 1, 1),
#    (695, 1, 1),
#    (696, 1, 1),
#    (700, 1, 1),
#    (763, 0, 1),
#    (772, 1, 1),
#    (796, 2, 1),
#    (826, 2, 1),
#    (846, 0, 2),
#    (857, 0, 2),
#    (858, 1, 1),
#    (859, 2, 1),
#    (861, 0, 1),
#    (862, 0, 2)],
#   [(94715, 2, 2)],
#   [(101970, 1, 1), (101974, 1, 1), (101977, 1, 1)],
#   [(106922, 1, 1),
#    (106939, 0, 1),
#    (106943, 1, 2),
#    (106953, 1, 1),
#    (106954, 1, 1),
#    (106976, 1, 1),
#    (107010, 0, 1),
#    (107013, 0, 1),
#    (107015, 0, 2),
#    (107016, 0, 1),
#    (107025, 1, 1),
#    (107026, 0, 2),
#    (107045, 1, 1),
#    (107056, 1, 1),
#    (107074, 1, 1),
#    (107075, 0, 2),
#    (107076, 1, 1),
#    (107077, 0, 1),
#    (107112, 1, 1),
#    (107113, 1, 1),
#    (107128, 1, 1),
#    (107130, 1, 1),
#    (107149, 0, 1),
#    (107151, 0, 1),
#    (107152, 1, 1),
#    (107166, 0, 1),
#    (107167, 0, 1),
#    (107168, 0, 2),
#    (107169, 0, 2),
#    (107175, 0, 1),
#    (107176, 2, 1),
#    (107186, 1, 2),
#    (107196, 1, 1),
#    (107197, 1, 1),
#    (107198, 1, 1),
#    (107222, 2, 1),
#    (107228, 1, 1),
#    (107231, 0, 2),
#    (107232, 1, 2),
#    (107248, 1, 1),
#    (107255, 1, 1),
#    (107256, 2, 1),
#    (107275, 0, 1),
#    (107276, 0, 1),
#    (107283, 1, 1),
#    (107284, 2, 4),
#    (107286, 1, 2),
#    (107310, 1, 1),
#    (107329, 1, 1),
#    (107333, 0, 1),
#    (107338, 1, 1),
#    (107349, 1, 2),
#    (107360, 0, 1),
#    (107363, 0, 1),
#    (107367, 0, 2),
#    (107370, 0, 2),
#    (107371, 0, 2),
#    (107390, 0, 1),
#    (107497, 1, 1),
#    (107509, 1, 1),
#    (107521, 2, 4),
#    (107522, 0, 2),
#    (107582, 1, 1),
#    (107585, 0, 1),
#    (107590, 1, 1),
#    (107626, 1, 1),
#    (107630, 1, 1),
#    (107636, 1, 1),
#    (107642, 1, 2),
#    (107647, 1, 1),
#    (107675, 1, 2),
#    (107678, 1, 1),
#    (107689, 0, 2),
#    (107691, 1, 1),
#    (107692, 2, 1),
#    (107708, 1, 1),
#    (107721, 1, 1),
#    (107731, 1, 1),
#    (107741, 0, 2),
#    (107742, 1, 1),
#    (107743, 0, 3),
#    (107748, 1, 1),
#    (107759, 0, 1),
#    (107763, 1, 1),
#    (107765, 1, 1),
#    (107767, 1, 2),
#    (107779, 1, 3),
#    (107780, 1, 2),
#    (107839, 0, 1),
#    (107922, 1, 1),
#    (107930, 1, 1),
#    (107937, 1, 2),
#    (107938, 1, 2),
#    (107947, 2, 1),
#    (107948, 1, 1),
#    (107956, 1, 1),
#    (107958, 1, 2),
#    (107967, 0, 1),
#    (107968, 0, 1),
#    (107969, 1, 1),
#    (107970, 1, 1),
#    (107971, 1, 1),
#    (107976, 1, 1),
#    (107978, 1, 1),
#    (107983, 1, 3),
#    (107986, 1, 1),
#    (108125, 2, 1),
#    (108126, 0, 1),
#    (108189, 1, 1),
#    (108190, 1, 1),
#    (108192, 1, 1),
#    (108227, 2, 2),
#    (108259, 1, 2),
#    (108277, 1, 1),
#    (108284, 1, 1),
#    (108360, 1, 1),
#    (108361, 1, 2),
#    (108413, 1, 2),
#    (108440, 0, 1),
#    (108449, 1, 1),
#    (108457, 2, 1),
#    (108459, 1, 1),
#    (108469, 1, 2),
#    (108472, 1, 1),
#    (108474, 1, 3),
#    (108475, 1, 1),
#    (108477, 2, 1),
#    (108478, 1, 1),
#    (108531, 1, 1),
#    (108534, 1, 1),
#    (108536, 1, 1),
#    (108539, 1, 2),
#    (108541, 2, 1),
#    (108547, 1, 1),
#    (108555, 0, 6),
#    (108556, 0, 6),
#    (108557, 2, 5),
#    (108562, 0, 1),
#    (108582, 1, 1),
#    (108584, 0, 3),
#    (108589, 1, 1),
#    (108608, 1, 1),
#    (108612, 1, 1),
#    (108641, 1, 1),
#    (108643, 1, 1),
#    (108645, 1, 1),
#    (108649, 1, 1),
#    (108652, 2, 1),
#    (108664, 1, 3),
#    (108675, 0, 2)]],
#  'CTGACACATAGTAG': [[(13414, 1, 1)]],
#  'AAGGCGAGTCTTCG': [[(59517, 1, 1),
#    (59523, 1, 1),
#    (59603, 1, 1),
#    (59605, 1, 2),
#    (59607, 1, 2),
#    (59617, 1, 1)],
#   [(59704, 1, 1)]],
#  'TTCGGATCTAATCA': [[(41879, 1, 2), (41925, 1, 2), (42139, 1, 1)]],
#  'TGCATGAGATTCAG': [[(65681, 1, 1)]],
#  'TAACGCTCAGGATA': [[(74432, 1, 1)]],
#  'CCGAATTCTATTGA': [[(77889, 0, 3), (77891, 1, 3), (77892, 1, 3)],
#   [(83449, 0, 1)]],
#  'GTAGAAAGGCTCAG': [[(106356, 0, 1)]],
#  'GTCCTCGTTCGTAC': [[(51058, 1, 1)], [(124378, 0, 1)]],
#  'GGAAATTCCCGTGG': [[(61878, 1, 1)]],
#  'AACTGCAGGTGCCA': [[(34478, 0, 1)]],
#  'ATAGGATCGTCAAC': [[(29109, 1, 1)]],
#  'TGGTTGGTGCTCAT': [[(77060, 1, 1)]],
#  'CTCTCGTCCGTGAT': [[(25371, 1, 1), (25372, 1, 1)]],
#  'GATGAATCCGCTCT': [[(51519, 1, 1), (51563, 1, 1), (51568, 1, 7)]],
#  'CTGATGTCGTAATT': [[(102866, 0, 1), (102867, 0, 1)]],
#  'TGCACAGTTATACT': [[(20347, 0, 1)],
#   [(40426, 0, 1)],
#   [(48821, 1, 1),
#    (48862, 1, 1),
#    (48863, 1, 1),
#    (48920, 0, 2),
#    (48925, 1, 2),
#    (48930, 1, 1),
#    (48931, 1, 1),
#    (48940, 1, 1),
#    (48976, 1, 1)]],
#  'CTGATGTCCGGTCG': [[(17451, 0, 1), (17452, 0, 1)]],
#  'TGTACGGTCTTCTT': [[(65513, 1, 1)]],
#  'TTGTGGTCATGGAA': [[(111309, 0, 1)]],
#  'GTACACCAATGGTA': [[(75548, 1, 1),
#    (75553, 2, 1),
#    (75564, 1, 3),
#    (75565, 1, 1),
#    (75566, 1, 1)]],
#  'GACGTTAGTCTTCG': [[(15698, 1, 1)], [(44079, 0, 1)]],
#  'CACAACTCGTAAGA': [[(13454, 2, 1),
#    (13456, 0, 2),
#    (13480, 1, 1),
#    (13486, 1, 2),
#    (13500, 1, 1),
#    (13501, 1, 1),
#    (13518, 1, 2),
#    (13519, 0, 1)]],
#  'AGATCCCACGAAAT': [[(99586, 2, 2),
#    (99587, 2, 2),
#    (99596, 1, 1),
#    (99597, 2, 1),
#    (99623, 0, 1)],
#   [(99841, 1, 4),
#    (99842, 2, 4),
#    (99843, 2, 3),
#    (99848, 1, 3),
#    (99849, 0, 1),
#    (99851, 1, 2),
#    (99852, 0, 3),
#    (99861, 0, 2),
#    (99864, 0, 4)]],
#  'TGACCAGTAACATG': [[(107566, 0, 2)]],
#  'AAGCTCAGACGTAT': [[(88519, 2, 1), (88527, 1, 1), (88536, 1, 1)]],
#  'GCCTCTAGGTGCCA': [[(68827, 0, 1), (68834, 1, 1), (68836, 1, 1)]],
#  'TCTCTAGTTTGCAC': [[(14834, 1, 1),
#    (14856, 1, 2),
#    (14871, 1, 1),
#    (14879, 1, 1),
#    (14891, 1, 1),
#    (14895, 1, 1),
#    (14899, 1, 1),
#    (14908, 1, 1),
#    (14912, 1, 3),
#    (14915, 1, 1),
#    (14918, 1, 1),
#    (14930, 1, 1),
#    (14944, 0, 1),
#    (14947, 1, 1),
#    (14954, 1, 1),
#    (14957, 1, 1),
#    (14959, 1, 1),
#    (14975, 1, 1),
#    (14979, 0, 2),
#    (14981, 1, 1),
#    (14989, 0, 2),
#    (15015, 1, 1)]],
#  'GTCCTCTCTCCTCG': [[(67660, 1, 2),
#    (67693, 1, 1),
#    (67697, 2, 1),
#    (67705, 1, 1),
#    (67729, 1, 1),
#    (67730, 0, 1),
#    (67731, 1, 1),
#    (67733, 1, 6),
#    (67734, 1, 2),
#    (67735, 1, 1),
#    (67753, 1, 2),
#    (67760, 1, 2),
#    (67766, 1, 2),
#    (67767, 1, 1),
#    (67779, 1, 1),
#    (67786, 1, 1),
#    (67788, 1, 1),
#    (67797, 1, 1),
#    (67803, 0, 1),
#    (67826, 0, 1),
#    (67839, 1, 1),
#    (67842, 1, 2),
#    (67863, 1, 1),
#    (67870, 1, 1),
#    (67900, 1, 1),
#    (67913, 0, 1),
#    (67915, 1, 1),
#    (67916, 2, 1),
#    (67921, 0, 1),
#    (67927, 1, 1)]],
#  'TGTGCATCAGATTT': [[(7832, 1, 1)]],
#  'AACCGTTCGTTCCC': [[(102866, 0, 1), (102867, 0, 1)]],
#  'GAGGCAAGTGAGCC': [[(81842, 0, 1)]],
#  'CTAGGTAGTTAGAC': [[(71451, 1, 1)]],
#  'AAAGTGCACAGTTC': [[(123089, 0, 1), (123094, 2, 1)]],
#  'TGAGAACATCGCAT': [[(95670, 1, 2), (95674, 0, 2)]],
#  'ACCTGATCTAATAC': [[(3153, 1, 1)],
#   [(66482, 1, 6), (66483, 1, 4), (66485, 1, 1), (66486, 0, 1), (66487, 1, 1)]],
#  'AAGTCCTCCGTGCG': [[(19761, 0, 1)]],
#  'ATACGCGTTACGTC': [[(77044, 1, 1),
#    (77049, 1, 1),
#    (77050, 2, 1),
#    (77051, 2, 2),
#    (77053, 1, 1),
#    (77058, 1, 1),
#    (77069, 1, 1),
#    (77073, 2, 1),
#    (77075, 1, 1),
#    (77100, 1, 1),
#    (77102, 1, 3),
#    (77103, 1, 2)]],
#  'TCTCCGGTTTCAAT': [[(57772, 1, 1),
#    (57776, 1, 2),
#    (57802, 1, 1),
#    (57806, 0, 2),
#    (57828, 1, 2),
#    (57844, 1, 1),
#    (57848, 1, 1),
#    (57850, 1, 1),
#    (57852, 0, 2),
#    (57853, 0, 1),
#    (57905, 1, 1)]],
#  'CTGAGTGTGACCTT': [[(34864, 0, 1),
#    (34865, 0, 1),
#    (34866, 0, 1),
#    (34867, 0, 1)]],
#  'CCAGTAAGCTTCGT': [[(78907, 1, 1)]],
#  'AAGACACATCGTGT': [[(44079, 0, 1)], [(50378, 0, 1), (50379, 0, 1)]],
#  'GCCTTCGTAGTTCC': [[(58594, 1, 2)]],
#  'TGCTTTCAAAGTCA': [[(4546, 1, 1)]],
#  'TGGTACAGAGACTT': [[(103021, 0, 1)],
#   [(119349, 1, 1),
#    (119360, 1, 1),
#    (119364, 1, 1),
#    (119470, 1, 1),
#    (119476, 1, 1),
#    (119529, 0, 1),
#    (119556, 1, 1),
#    (119557, 1, 1)]],
#  'GATCTGCAATCGGG': [[(50150, 0, 1)]],
#  'GCCCTTCAATCCGT': [[(295, 0, 2), (296, 0, 5), (297, 0, 6)],
#   [(28789, 0, 2), (28811, 0, 1), (28823, 1, 1), (28833, 1, 1)],
#   [(117977, 2, 1)]],
#  'ACCCTCAGCCGATG': [[(17451, 0, 2), (17452, 0, 2)],
#   [(98666, 0, 1), (98667, 0, 1), (98669, 0, 1)]],
#  'TACACGAGGTACTA': [[(73689, 1, 2), (73747, 1, 1), (73767, 1, 1)],
#   [(73904, 1, 2),
#    (73942, 1, 1),
#    (73971, 1, 1),
#    (73973, 1, 1),
#    (73985, 1, 1),
#    (73988, 2, 1),
#    (73989, 0, 1),
#    (74000, 2, 1),
#    (74003, 1, 2),
#    (74030, 1, 1),
#    (74067, 1, 1),
#    (74073, 1, 1),
#    (74074, 0, 1),
#    (74091, 1, 1),
#    (74107, 1, 1),
#    (74139, 1, 1),
#    (74171, 1, 2),
#    (74185, 1, 1),
#    (74245, 1, 1)],
#   [(74394, 1, 1),
#    (74401, 1, 1),
#    (74432, 1, 1),
#    (74481, 0, 1),
#    (74513, 1, 1),
#    (74525, 1, 1),
#    (74527, 1, 1),
#    (74549, 1, 4),
#    (74552, 1, 3),
#    (74582, 1, 1),
#    (74624, 1, 2),
#    (74629, 1, 2),
#    (74705, 1, 2),
#    (74706, 1, 1),
#    (74710, 1, 2),
#    (74718, 1, 1),
#    (74723, 1, 1),
#    (74726, 1, 3),
#    (74734, 1, 3),
#    (74753, 0, 1),
#    (74754, 0, 1),
#    (74771, 1, 1),
#    (74781, 2, 1),
#    (74792, 1, 1),
#    (74820, 1, 1)]],
#  'CGGTTAAGCCCTTA': [[(31363, 0, 1)]],
#  'CGTGATGTGTAGTA': [[(89039, 1, 1)],
#   [(105866, 1, 1),
#    (105883, 1, 1),
#    (105894, 0, 1),
#    (105895, 1, 1),
#    (105961, 1, 1),
#    (105978, 1, 2),
#    (106019, 1, 1),
#    (106065, 1, 1),
#    (106080, 0, 1),
#    (106084, 1, 2)]],
#  'TCACGATCTGACCA': [[(81603, 0, 1)], [(123904, 1, 1), (123906, 0, 1)]],
#  'TGTAGCGTTAACCC': [[(117574, 1, 1), (117575, 1, 1)]],
#  'GTAGCTAGCGTGCA': [[(40183, 0, 1)]],
#  'TTGCGAAGGTTCAA': [[(349, 1, 1)],
#   [(58105, 1, 1),
#    (58106, 1, 1),
#    (58107, 0, 1),
#    (58108, 1, 1),
#    (58118, 1, 1),
#    (58125, 1, 1),
#    (58130, 2, 1)]],
#  'CTTAGGTCGTAGGG': [[(118290, 0, 2), (118295, 1, 1)]],
#  'GCGAGATCTCGGTA': [[(3559, 1, 1),
#    (3561, 1, 1),
#    (3585, 1, 2),
#    (3590, 1, 1),
#    (3593, 1, 1),
#    (3603, 2, 1),
#    (3604, 1, 1),
#    (3605, 0, 1),
#    (3606, 1, 2),
#    (3621, 1, 3),
#    (3629, 1, 1),
#    (3630, 1, 1),
#    (3639, 2, 1),
#    (3700, 1, 1),
#    (3741, 1, 3)]],
#  'AGACAACACGTACT': [[(31326, 0, 1)], [(97399, 1, 1)]],
#  'TGGAGGGTATCTTA': [[(101609, 1, 1)],
#   [(101889, 0, 2), (101925, 0, 1), (101927, 2, 1)]],
#  'CGGAAGGTGTCTTG': [[(90985, 1, 1)]],
#  'GTGTACAGTTCCGT': [[(85286, 1, 1)],
#   [(120528, 1, 1),
#    (120688, 1, 1),
#    (120722, 1, 1),
#    (120737, 0, 1),
#    (120775, 0, 2),
#    (120776, 1, 1),
#    (120777, 1, 1),
#    (120792, 1, 1),
#    (120818, 1, 1),
#    (120832, 2, 1),
#    (120833, 1, 1),
#    (120842, 1, 1),
#    (120844, 1, 2),
#    (120850, 1, 1),
#    (120883, 1, 1),
#    (120894, 0, 1),
#    (120899, 2, 1),
#    (120900, 0, 1),
#    (120908, 1, 1),
#    (120910, 1, 1),
#    (120911, 0, 1),
#    (120912, 0, 3),
#    (120986, 1, 1),
#    (121131, 1, 1),
#    (121132, 2, 1),
#    (121134, 1, 1),
#    (121135, 1, 2),
#    (121136, 1, 1),
#    (121195, 2, 1),
#    (121276, 1, 1),
#    (121287, 1, 1),
#    (121289, 1, 1),
#    (121290, 1, 1),
#    (121296, 1, 2)]],
#  'TCGTCCAGCTCCTA': [[(12600, 1, 1),
#    (12601, 2, 1),
#    (12625, 1, 1),
#    (12626, 1, 1),
#    (12654, 1, 1),
#    (12701, 1, 1),
#    (12752, 1, 1),
#    (12769, 0, 1),
#    (12771, 0, 1),
#    (12908, 1, 2),
#    (12913, 1, 1),
#    (12915, 1, 1),
#    (12916, 1, 1)]],
#  'TGTTTCTCCCTAAG': [[(100342, 1, 1)]],
#  'CTGACACATCCAAC': [[(27837, 0, 2)]],
#  'GCATCAGTACCGTT': [[(12673, 1, 1), (12674, 0, 1)]],
#  'GCCTAAGTTTTAAC': [[(112698, 0, 2)]],
#  'GCTTGAGTATAGTG': [[(75621, 1, 1),
#    (75662, 1, 1),
#    (75674, 0, 1),
#    (75683, 1, 1),
#    (75685, 0, 1),
#    (75687, 1, 1),
#    (75690, 1, 1),
#    (75697, 1, 1),
#    (75705, 0, 1),
#    (75706, 2, 1),
#    (75707, 2, 2),
#    (75709, 0, 1),
#    (75717, 1, 2),
#    (75733, 0, 1),
#    (75770, 1, 1),
#    (75771, 0, 2),
#    (75773, 2, 1),
#    (75799, 1, 1),
#    (75802, 2, 1),
#    (75817, 1, 3),
#    (75827, 2, 1),
#    (75855, 0, 3),
#    (75866, 0, 1),
#    (75869, 1, 1),
#    (75870, 0, 1),
#    (75893, 1, 1),
#    (75913, 0, 1),
#    (75930, 1, 1),
#    (75931, 0, 1),
#    (75933, 1, 1),
#    (75936, 1, 1),
#    (75943, 0, 2),
#    (76011, 1, 1),
#    (76022, 0, 1),
#    (76023, 0, 2),
#    (76025, 1, 2),
#    (76028, 0, 1),
#    (76033, 0, 2),
#    (76034, 1, 1),
#    (76043, 1, 1),
#    (76059, 1, 1),
#    (76074, 2, 1),
#    (76079, 2, 1),
#    (76089, 0, 1),
#    (76099, 1, 1),
#    (76118, 1, 1),
#    (76122, 1, 1),
#    (76129, 1, 1),
#    (76130, 2, 1)],
#   [(103315, 0, 1)]],
#  'TGGTACTCACTGTG': [[(56066, 1, 1), (56071, 1, 2), (56072, 0, 2)],
#   [(56141, 0, 1), (56144, 1, 1), (56145, 1, 1)],
#   [(56227, 1, 2)]],
#  'TAGCGTCAGTCCTA': [[(24844, 1, 1)]],
#  'CAACACTCCTTACT': [[(65798, 1, 1), (65831, 1, 1)]],
#  'GAACCTTCTGTTCT': [[(79649, 0, 1)]],
#  'GAGGCATCACTGTG': [[(41605, 0, 1)]],
#  'TGTGCATCATACGC': [[(47096, 1, 1)], [(111425, 1, 1), (111426, 0, 1)]],
#  'TGGCTATCCGTAAC': [[(81826, 1, 1)]],
#  'GCGAGAAGCTCAGG': [[(87108, 0, 1)]],
#  'TCCGAAAGCATAAC': [[(78597, 0, 1)]],
#  'CAAACCTCGTTCCC': [[(15792, 0, 1),
#    (15793, 0, 1),
#    (15795, 1, 1),
#    (15796, 1, 1),
#    (15848, 1, 1)],
#   [(16037, 2, 1),
#    (16071, 1, 1),
#    (16072, 1, 1),
#    (16103, 1, 1),
#    (16104, 2, 1),
#    (16178, 0, 1),
#    (16185, 1, 1),
#    (16186, 1, 1),
#    (16187, 1, 1),
#    (16188, 1, 1),
#    (16232, 1, 1)],
#   [(112893, 1, 1), (112899, 0, 2)]],
#  'GGAAATGTTTAGGA': [[(111941, 0, 1)]],
#  'TACGCACACTCCGG': [[(71500, 0, 1), (71501, 0, 1)]],
#  'CCCGTTTCTTACTC': [[(6082, 1, 2)],
#   [(47569, 1, 1)],
#   [(86340, 2, 1), (86353, 1, 1)]],
#  'CCTAGACATTACTA': [[(13881, 1, 1)],
#   [(31805, 1, 1)],
#   [(46114, 0, 1)],
#   [(59794, 1, 1)],
#   [(61563, 1, 1)],
#   [(63588, 1, 1)],
#   [(76741, 1, 1), (76742, 1, 1)],
#   [(103949, 1, 1)],
#   [(110385, 1, 2)],
#   [(115427, 1, 1), (115428, 1, 1)]],
#  'AGCGAGAGCCCTGC': [[(87846, 1, 2),
#    (87850, 1, 1),
#    (87870, 1, 1),
#    (87883, 0, 1),
#    (87884, 1, 1),
#    (87921, 1, 1),
#    (87952, 1, 1),
#    (87981, 1, 1)],
#   [(88149, 1, 1),
#    (88174, 1, 1),
#    (88178, 1, 1),
#    (88192, 1, 1),
#    (88193, 1, 1),
#    (88196, 1, 1),
#    (88237, 1, 1)],
#   [(88305, 1, 1)],
#   [(88387, 0, 1),
#    (88486, 0, 1),
#    (88487, 0, 1),
#    (88495, 0, 1),
#    (88568, 1, 2),
#    (88573, 1, 1),
#    (88574, 1, 1)],
#   [(88753, 1, 1),
#    (88760, 1, 1),
#    (88775, 1, 1),
#    (88786, 1, 1),
#    (88787, 1, 2),
#    (88788, 1, 3),
#    (88790, 1, 2),
#    (88791, 1, 2),
#    (88799, 1, 1)],
#   [(88938, 1, 1),
#    (88966, 1, 1),
#    (88968, 1, 2),
#    (88976, 1, 1),
#    (88980, 1, 1),
#    (88981, 1, 2),
#    (88992, 0, 1)]],
#  'GGCAAGTCGTTCCC': [[(17931, 0, 1), (17991, 0, 1)],
#   [(18109, 1, 2),
#    (18172, 1, 1),
#    (18270, 1, 1),
#    (18271, 2, 1),
#    (18279, 1, 1),
#    (18381, 0, 1),
#    (18382, 0, 1)]],
#  'ACGTACAGTGGGAA': [[(349, 1, 6)]],
#  'CTCCGTAGGCTATA': [[(41351, 0, 1)], [(103578, 1, 1)]],
#  'GACGTTCAGTCAGG': [[(78674, 0, 1)]],
#  'AAAGGTAGCAAGTT': [[(31827, 0, 1)]],
#  'GGATCTGTTAAACG': [[(86118, 0, 1)]],
#  'ATCCAGTCCTGAGT': [[(115458, 1, 1)]],
#  'AACTGCAGAACTTG': [[(15972, 1, 1),
#    (15973, 1, 1),
#    (15974, 1, 2),
#    (15977, 1, 1),
#    (15978, 1, 2),
#    (15983, 1, 2)],
#   [(79280, 0, 1)],
#   [(98516, 0, 1), (98522, 1, 3), (98524, 1, 2), (98526, 1, 1), (98528, 1, 1)]],
#  'CAAAGAGTACGGTG': [[(25372, 1, 1)]],
#  'TGTCGACAATCTTA': [[(61538, 0, 1),
#    (61543, 2, 1),
#    (61547, 0, 1),
#    (61555, 1, 1),
#    (61560, 1, 3),
#    (61563, 1, 1),
#    (61574, 2, 1),
#    (61586, 1, 17),
#    (61587, 1, 8),
#    (61594, 1, 2),
#    (61595, 1, 1),
#    (61596, 1, 2)]],
#  'GCCATAGTCTTGCA': [[(120331, 0, 1), (120336, 1, 1)]],
#  'TAGTCGCATGTTCG': [[(36892, 0, 1), (36893, 0, 1)]],
#  'AAAGCACAGTTAGA': [[(59915, 1, 1), (59922, 1, 2)]],
#  'CCTCCACAGTAGAT': [[(97159, 2, 1), (97162, 1, 1), (97163, 1, 1)]],
#  'ACGCTAAGACGGCT': [[(69073, 0, 2), (69074, 0, 2), (69075, 1, 2)]],
#  'TCTGTTGTTTAACT': [[(48777, 1, 1),
#    (48800, 1, 3),
#    (48818, 0, 1),
#    (48838, 1, 1),
#    (48849, 1, 1),
#    (48850, 1, 1),
#    (48866, 1, 1),
#    (48870, 0, 1),
#    (48903, 1, 2),
#    (48905, 1, 2)]],
#  'GCTAACCAACTGTC': [[(40282, 1, 2),
#    (40315, 1, 1),
#    (40365, 1, 1),
#    (40378, 0, 1)]],
#  'TTCTCAGTATTGTT': [[(34349, 2, 1), (34361, 1, 1)], [(52335, 0, 2)]],
#  'GCCTCTTCTACAAT': [[(106355, 0, 1)]],
#  'CGATACTCATCTTC': [[(122605, 1, 1)]],
#  'TTTGTCGTTCTAGC': [[(94867, 1, 1)]],
#  'TCTCCGAGATTGAC': [[(25940, 1, 1)]],
#  'ACCAACAGGAGATG': [[(56227, 0, 1),
#    (56251, 1, 1),
#    (56267, 1, 2),
#    (56295, 1, 1),
#    (56309, 1, 3),
#    (56316, 1, 1),
#    (56318, 1, 1),
#    (56319, 0, 1),
#    (56339, 1, 1),
#    (56340, 1, 2),
#    (56344, 0, 1),
#    (56365, 1, 1),
#    (56367, 1, 1),
#    (56368, 1, 1),
#    (56369, 1, 2),
#    (56370, 1, 1),
#    (56375, 1, 1),
#    (56383, 1, 1),
#    (56397, 0, 1),
#    (56405, 1, 2),
#    (56412, 0, 5),
#    (56415, 0, 2),
#    (56429, 0, 2),
#    (56433, 0, 3),
#    (56434, 1, 1),
#    (56435, 1, 1),
#    (56436, 0, 1),
#    (56473, 1, 2)],
#   [(56578, 1, 3), (56579, 1, 2), (56580, 1, 1), (56583, 1, 1), (56588, 1, 1)],
#   [(106355, 0, 3)]],
#  'GAGAATCAGGAATT': [[(124245, 1, 1)]],
#  'CGTAGTTCGAATGA': [[(14047, 0, 1)]],
#  'AGACCTTCCGTAGT': [[(17721, 2, 2)],
#   [(81707, 1, 1), (81709, 1, 1)],
#   [(81793, 0, 1)]],
#  'GTGGGACAAACTCC': [[(111007, 1, 1),
#    (111009, 0, 1),
#    (111017, 1, 3),
#    (111019, 0, 3)]],
#  'ACTCTTAGGCCTAG': [[(75637, 2, 1)]],
#  'TAGCGTAGCGATTA': [[(53728, 2, 1),
#    (53766, 0, 1),
#    (53787, 0, 1),
#    (53788, 1, 1),
#    (53800, 1, 1),
#    (53831, 0, 1),
#    (53832, 1, 1),
#    (53852, 1, 1),
#    (53890, 1, 1),
#    (53892, 1, 2),
#    (53894, 1, 1),
#    (53895, 1, 1),
#    (53914, 1, 1),
#    (53935, 0, 1),
#    (53942, 1, 1)],
#   [(54153, 0, 1)],
#   [(66792, 0, 4),
#    (66795, 2, 2),
#    (66798, 0, 1),
#    (66799, 1, 2),
#    (66800, 0, 1),
#    (66801, 1, 1),
#    (66816, 0, 3),
#    (66823, 1, 2),
#    (66825, 0, 1),
#    (66826, 1, 2),
#    (66831, 1, 1),
#    (66832, 2, 3),
#    (66833, 0, 2),
#    (66842, 0, 1),
#    (66846, 0, 1),
#    (66850, 1, 1),
#    (66851, 1, 1),
#    (66852, 1, 2),
#    (66853, 2, 1),
#    (66864, 1, 1),
#    (66874, 1, 2),
#    (66877, 2, 1),
#    (66904, 2, 2),
#    (66940, 1, 1),
#    (66941, 1, 1),
#    (66999, 2, 2),
#    (67001, 0, 1)]],
#  'GGACAGGTTGTTTA': [[(91695, 0, 1), (91696, 0, 1)]],
#  'TCCACCCATTTGTA': [[(76022, 0, 1)], [(84855, 1, 1)], [(106355, 0, 1)]],
#  'CGATACTCCGAGTT': [[(46384, 1, 4), (46385, 0, 10)],
#   [(71128, 0, 1), (71129, 1, 1)]],
#  'AGGTTCGTCAGGTG': [[(27466, 0, 1)]],
#  'ACCAGTAGTATCAG': [[(77714, 1, 2), (77715, 1, 1)]],
#  'TCCTTACATCTTGG': [[(2797, 1, 1)],
#   [(2930, 1, 1),
#    (2932, 1, 1),
#    (2943, 0, 1),
#    (2956, 1, 2),
#    (2958, 1, 1),
#    (2963, 1, 1),
#    (2968, 1, 1),
#    (3033, 0, 1)]],
#  'ATCCAGTCTATTGA': [[(46384, 0, 1)]],
#  'CGACATCATTCGAC': [[(11707, 1, 1),
#    (11708, 0, 1),
#    (11710, 1, 1),
#    (11711, 0, 1),
#    (11728, 1, 1),
#    (11729, 2, 2),
#    (11748, 1, 2),
#    (11749, 2, 1),
#    (11753, 2, 1)]],
#  'TCTGTTCATTAGGA': [[(80780, 1, 2), (80781, 0, 2)], [(86118, 0, 1)]],
#  'CTATTCGTACCTAC': [[(102417, 1, 1),
#    (102418, 0, 1),
#    (102436, 1, 2),
#    (102437, 1, 1),
#    (102440, 0, 1),
#    (102443, 0, 2),
#    (102448, 0, 1)]],
#  'GTTGGTTCGATTCG': [[(1859, 1, 1)]],
#  'ACGAAATCAGTGCT': [[(98509, 1, 3),
#    (98511, 1, 1),
#    (98517, 1, 1),
#    (98518, 0, 1)],
#   [(122951, 1, 1),
#    (122983, 0, 1),
#    (122985, 0, 1),
#    (122990, 0, 1),
#    (123008, 0, 2),
#    (123021, 2, 1),
#    (123035, 2, 1),
#    (123094, 1, 1),
#    (123095, 0, 1),
#    (123098, 1, 1)],
#   [(123920, 1, 1), (123921, 0, 1)]],
#  'TCCAAGGTTGTAAG': [[(33176, 0, 1), (33177, 0, 1)],
#   [(52199, 0, 1)],
#   [(76310, 0, 1)],
#   [(77043, 1, 1)],
#   [(101633, 1, 1)],
#   [(102047, 0, 1)]],
#  'GGATTCGTGTTAAG': [[(38763, 1, 1)],
#   [(56291, 1, 1), (56334, 0, 1), (56335, 0, 1), (56423, 1, 1), (56433, 1, 1)]],
#  'ATGGCTCATTCTCT': [[(113502, 2, 1)]],
#  'TGGTGTAGAGTTTG': [[(57186, 1, 2)], [(57290, 1, 1)]],
#  'GAAGTATCTCAAGC': [[(7884, 1, 1)],
#   [(54479, 1, 1), (54480, 0, 1), (54481, 1, 1), (54482, 1, 1), (54483, 1, 1)],
#   [(94268, 1, 1), (94321, 1, 1), (94349, 2, 1), (94357, 1, 2), (94365, 0, 1)],
#   [(94429, 1, 2),
#    (94440, 0, 1),
#    (94448, 0, 1),
#    (94454, 1, 1),
#    (94486, 0, 1),
#    (94493, 0, 1),
#    (94555, 1, 1)],
#   [(94998, 1, 1),
#    (95019, 0, 1),
#    (95022, 1, 2),
#    (95024, 0, 1),
#    (95025, 0, 1),
#    (95032, 0, 2),
#    (95055, 2, 1)]],
#  'CACCCTTCATCTGG': [[(106355, 0, 1)]],
#  'GGTCTATCCTTAGG': [[(34478, 0, 1)], [(87763, 0, 1)], [(109638, 0, 1)]],
#  'TGACTGTCCTTTGT': [[(106355, 0, 1)],
#   [(125541, 0, 1),
#    (125547, 0, 1),
#    (125577, 1, 1),
#    (125590, 1, 1),
#    (125625, 0, 3),
#    (125627, 0, 3),
#    (125629, 0, 1),
#    (125667, 1, 1),
#    (125673, 1, 1),
#    (125691, 0, 1)]],
#  'TAGAGACAAATCGA': [[(93399, 0, 1)]],
#  'AAGAGTTCTTCGAG': [[(33380, 1, 1),
#    (33415, 1, 1),
#    (33427, 1, 1),
#    (33431, 1, 1),
#    (33432, 1, 2),
#    (33642, 1, 1),
#    (33663, 0, 1),
#    (33713, 1, 1),
#    (33714, 1, 1),
#    (33731, 0, 1)],
#   [(61837, 0, 1), (61855, 0, 2), (61873, 0, 1), (61874, 0, 1), (61877, 1, 1)],
#   [(62055, 1, 1), (62096, 1, 1), (62100, 1, 1)]],
#  'CGAACTAGAGCTGC': [[(9316, 0, 1), (9318, 1, 2), (9337, 1, 2), (9355, 0, 1)],
#   [(9499, 1, 1),
#    (9513, 2, 1),
#    (9536, 1, 1),
#    (9542, 1, 5),
#    (9579, 0, 1),
#    (9583, 1, 1),
#    (9585, 1, 1),
#    (9587, 1, 1),
#    (9590, 0, 1)],
#   [(119007, 0, 1)]],
#  'ACCAACGTATATCT': [[(107566, 0, 1)]],
#  'CGTTTTCATTCAAT': [[(23742, 0, 1)]],
#  'CGAGAGAGTCTTGC': [[(60099, 0, 1), (60100, 1, 1)]],
#  'TGATGCTCGTTACG': [[(78482, 0, 2)], [(119221, 1, 1)]],
#  'AGGAATGTATTCTA': [[(83751, 1, 8),
#    (83753, 1, 2),
#    (83762, 1, 2),
#    (83765, 1, 1),
#    (83767, 1, 3),
#    (83768, 1, 1),
#    (83769, 1, 1)],
#   [(84860, 1, 1)],
#   [(119191, 1, 1),
#    (119263, 0, 1),
#    (119291, 1, 1),
#    (119298, 1, 2),
#    (119308, 2, 3)]],
#  'TGTGCACACTTTCT': [[(74659, 0, 1)]],
#  'GGTAAAAGATACCA': [[(72367, 1, 1), (72371, 1, 1)]],
#  'GAATCCTCACGTAC': [[(349, 1, 3)]],
#  'AGTCGTTCTGCGAT': [[(349, 0, 1)], [(87149, 1, 1), (87150, 1, 1)]],
#  'TGCCAAGTGCATTC': [[(31938, 0, 1)]],
#  'GTGTACGTATGGGC': [[(25031, 1, 1)],
#   [(36732, 1, 2),
#    (36766, 1, 1),
#    (36877, 1, 1),
#    (36878, 1, 1),
#    (36879, 1, 1),
#    (36880, 1, 1),
#    (36889, 1, 1),
#    (36892, 0, 1),
#    (36900, 0, 1),
#    (36901, 1, 1),
#    (36902, 1, 1),
#    (36908, 1, 1),
#    (36910, 1, 2),
#    (36914, 1, 1),
#    (37018, 0, 1),
#    (37035, 1, 3),
#    (37051, 1, 2),
#    (37052, 0, 2),
#    (37053, 0, 2),
#    (37057, 0, 1),
#    (37068, 0, 1),
#    (37122, 1, 1),
#    (37145, 1, 1),
#    (37173, 1, 1),
#    (37187, 1, 1),
#    (37189, 1, 3),
#    (37202, 1, 2),
#    (37203, 0, 2),
#    (37205, 0, 1),
#    (37217, 1, 1),
#    (37272, 1, 1),
#    (37273, 0, 1),
#    (37382, 0, 1),
#    (37428, 1, 1)],
#   [(37562, 1, 1),
#    (37585, 0, 1),
#    (37599, 2, 1),
#    (37600, 2, 1),
#    (37601, 1, 1),
#    (37620, 0, 1),
#    (37621, 1, 1),
#    (37623, 0, 1),
#    (37625, 1, 1),
#    (37627, 1, 1),
#    (37630, 1, 1),
#    (37682, 0, 1)],
#   [(110756, 0, 2)]],
#  'TACAGCGTTACGCT': [[(91328, 0, 1), (91329, 0, 1), (91330, 0, 1)]],
#  'GACCATTCCTAGCA': [[(106355, 0, 1)]],
#  'TACGACAGAGCTTA': [[(66731, 1, 1),
#    (66732, 1, 2),
#    (66758, 1, 1),
#    (66776, 0, 1)]],
#  'GTGTCAGTCATCAC': [[(9220, 1, 1)]],
#  'CCAGTACAGGAATT': [[(50216, 1, 1)]],
#  'TACCTTTCGTTGTG': [[(28744, 1, 1),
#    (28749, 1, 1),
#    (28751, 1, 2),
#    (28785, 1, 1),
#    (28789, 1, 2),
#    (28800, 1, 1),
#    (28803, 1, 1),
#    (28823, 2, 2),
#    (28877, 1, 1),
#    (28907, 0, 1),
#    (28920, 1, 1),
#    (28932, 0, 1),
#    (28943, 0, 2),
#    (28945, 0, 1),
#    (28946, 0, 1),
#    (28947, 0, 1),
#    (28958, 1, 1),
#    (28968, 0, 3),
#    (28969, 1, 2),
#    (28970, 1, 1),
#    (28974, 0, 4),
#    (28975, 0, 1),
#    (28980, 0, 1),
#    (28989, 1, 2),
#    (28993, 1, 1),
#    (29002, 1, 1)],
#   [(39259, 1, 1)]],
#  'TAGCACTCAGACTC': [[(42767, 1, 1),
#    (42776, 1, 2),
#    (42778, 1, 1),
#    (42779, 1, 1)],
#   [(68674, 0, 1)]],
#  'GCAGGACACTGGTT': [[(349, 1, 2)],
#   [(20943, 0, 1)],
#   [(66789, 1, 1),
#    (66790, 1, 1),
#    (66791, 2, 1),
#    (66792, 1, 3),
#    (66793, 1, 2),
#    (66795, 1, 3),
#    (66829, 2, 3),
#    (66832, 1, 3),
#    (66834, 1, 1),
#    (66846, 1, 2),
#    (66853, 1, 1),
#    (66861, 0, 2),
#    (66870, 0, 2),
#    (66874, 2, 3),
#    (66898, 1, 1)]],
#  'ACCCTCTCTCGGTA': [[(34478, 0, 1)], [(106355, 0, 1)], [(113104, 1, 1)]],
#  'ATACCGCAGATAAC': [[(13965, 0, 1)]],
#  'ATGGAAGTACATGA': [[(52266, 1, 2),
#    (52299, 1, 1),
#    (52300, 2, 1),
#    (52301, 1, 1),
#    (52302, 0, 2),
#    (52303, 0, 2),
#    (52304, 0, 2),
#    (52323, 1, 1),
#    (52325, 1, 1),
#    (52326, 1, 2),
#    (52337, 1, 1),
#    (52344, 1, 1),
#    (52347, 0, 1),
#    (52394, 1, 1),
#    (52417, 1, 1),
#    (52453, 0, 3),
#    (52454, 0, 2),
#    (52467, 1, 1),
#    (52494, 1, 1)]],
#  'TCCAGAGTGTTGTC': [[(23772, 1, 2)], [(62845, 1, 2)]],
#  'GATGAAAGCTACAA': [[(96788, 1, 2)]],
#  'CCTAAGAGAACTTG': [[(58295, 0, 1)]],
#  'TGTAGCAGTTGATG': [[(40608, 1, 1)],
#   [(41116, 1, 1), (41117, 1, 1)],
#   [(52592, 1, 1)],
#   [(115446, 2, 1)]],
#  'TGTCGATCAATTGT': [[(42959, 1, 1)],
#   [(78607, 1, 1),
#    (78608, 1, 1),
#    (78616, 0, 1),
#    (78667, 0, 1),
#    (78669, 0, 1),
#    (78675, 0, 1)],
#   [(78940, 1, 1)],
#   [(78980, 0, 1), (78999, 0, 1)],
#   [(85083, 1, 2)]],
#  'GCACATAGTAACTG': [[(5184, 0, 1)], [(67087, 1, 2)]],
#  'GACAGGAGGCCTAG': [[(61819, 0, 1),
#    (61820, 0, 1),
#    (61821, 0, 1),
#    (61822, 0, 1)],
#   [(77748, 0, 1)]],
#  'CATCGATCTTCACT': [[(126017, 1, 1)]],
#  'TAGCACTCCTGCTC': [[(64808, 2, 1)],
#   [(118270, 1, 2)],
#   [(118410, 1, 2),
#    (118432, 1, 2),
#    (118458, 1, 1),
#    (118492, 1, 1),
#    (118497, 0, 1),
#    (118498, 2, 1),
#    (118502, 1, 5),
#    (118509, 1, 2),
#    (118512, 1, 5),
#    (118513, 1, 3),
#    (118515, 1, 1),
#    (118518, 1, 2)],
#   [(118590, 1, 1), (118592, 1, 1)],
#   [(118704, 1, 1),
#    (118742, 1, 2),
#    (118744, 1, 2),
#    (118745, 1, 1),
#    (118746, 2, 1)],
#   [(118944, 1, 1)]],
#  'TGTAGCTCGTTTCT': [[(56849, 1, 1), (56850, 1, 1)]],
#  'GATTCGGTTATTGT': [[(67079, 1, 1)]],
#  'ACCTGATCGACGTT': [[(41812, 0, 1)]],
#  'GACGTTAGAAGATA': [[(28134, 1, 1)]],
#  'CTAACGAGCGTATA': [[(38324, 0, 1), (38325, 2, 1)], [(54174, 0, 1)]],
#  'GTCTAGAGATGCTA': [[(9241, 0, 1), (9242, 0, 1)], [(43490, 1, 2)]],
#  'GTTCAGAGCGTGGT': [[(29425, 1, 2),
#    (29426, 1, 1),
#    (29441, 1, 1),
#    (29490, 1, 1),
#    (29494, 1, 2),
#    (29499, 1, 1),
#    (29501, 1, 1),
#    (29515, 0, 1),
#    (29528, 1, 1),
#    (29529, 1, 1)],
#   [(46715, 0, 1), (46716, 0, 1)],
#   [(52159, 1, 1), (52165, 2, 1)]],
#  'GCCCTTAGGTACTA': [[(18257, 1, 1),
#    (18260, 2, 1),
#    (18262, 0, 1),
#    (18280, 1, 2),
#    (18281, 1, 2),
#    (18287, 1, 1),
#    (18301, 0, 1),
#    (18313, 0, 1),
#    (18314, 1, 1),
#    (18323, 1, 1),
#    (18326, 1, 1),
#    (18327, 1, 1),
#    (18330, 1, 1),
#    (18337, 1, 3),
#    (18340, 1, 2),
#    (18349, 1, 1),
#    (18357, 1, 1),
#    (18358, 1, 1),
#    (18365, 1, 1),
#    (18366, 2, 1),
#    (18367, 1, 1),
#    (18368, 2, 1),
#    (18370, 1, 2),
#    (18377, 1, 2),
#    (18389, 1, 1),
#    (18447, 1, 1)],
#   [(18615, 1, 1),
#    (18625, 1, 3),
#    (18626, 1, 2),
#    (18627, 0, 2),
#    (18628, 1, 2),
#    (18652, 1, 1),
#    (18724, 0, 1),
#    (18727, 1, 1),
#    (18731, 1, 1),
#    (18733, 1, 1),
#    (18741, 1, 2),
#    (18755, 0, 1),
#    (18779, 1, 1),
#    (18783, 1, 2),
#    (18789, 1, 3),
#    (18811, 1, 1),
#    (18812, 0, 1),
#    (18815, 1, 2),
#    (18827, 1, 1),
#    (18847, 1, 1),
#    (18850, 1, 1),
#    (18869, 0, 1),
#    (18883, 1, 1),
#    (18884, 1, 1),
#    (18895, 0, 1),
#    (18908, 1, 1),
#    (18919, 1, 1),
#    (18944, 1, 3),
#    (18998, 1, 1),
#    (19024, 1, 1),
#    (19056, 1, 1),
#    (19064, 1, 1),
#    (19066, 0, 3),
#    (19091, 1, 1),
#    (19095, 1, 1),
#    (19108, 2, 1)],
#   [(40399, 2, 1)],
#   [(43133, 0, 2)]],
#  'CTTCTACACAATCC': [[(106355, 0, 1)]],
#  'CCTAGATCGTGACT': [[(13368, 0, 1)],
#   [(46419, 1, 1), (46421, 0, 2), (46428, 1, 1), (46437, 1, 4)],
#   [(46469, 1, 2)],
#   [(46690, 1, 1),
#    (46705, 2, 1),
#    (46706, 0, 1),
#    (46712, 2, 1),
#    (46728, 1, 1),
#    (46729, 1, 1)],
#   [(50947, 0, 1)],
#   [(106355, 0, 1)]],
#  'CCCTACGTTATATC': [[(23277, 0, 1),
#    (23278, 1, 2),
#    (23280, 1, 2),
#    (23282, 0, 1)],
#   [(73187, 1, 1),
#    (73191, 1, 1),
#    (73199, 0, 1),
#    (73231, 1, 1),
#    (73265, 2, 2),
#    (73267, 0, 1),
#    (73268, 1, 2),
#    (73279, 1, 2)]],
#  'CGTAACTCTCTACT': [[(39731, 1, 1), (39736, 1, 1)], [(103141, 1, 2)]],
#  'TCTATCTCTTGGAC': [[(349, 1, 1)], [(57183, 0, 1)]],
#  'CTACTTAGCTGTAA': [[(76022, 0, 1)]],
#  'TCTATCTCTGTGCA': [[(60955, 1, 2), (60960, 0, 1), (60993, 0, 2)]],
#  'AAAGCAAGTATTTC': [[(34848, 1, 1),
#    (34849, 1, 1),
#    (34851, 1, 1),
#    (34852, 1, 1),
#    (34853, 1, 1),
#    (34857, 1, 1),
#    (34858, 0, 1),
#    (34865, 1, 1),
#    (34866, 1, 1),
#    (34867, 1, 1),
#    (34868, 1, 1)],
#   [(40282, 0, 1), (40299, 0, 1), (40301, 1, 1), (40313, 1, 1), (40407, 1, 1)],
#   [(59829, 1, 1)],
#   [(61819, 0, 1), (61820, 0, 1), (61821, 0, 1), (61822, 0, 1)]],
#  'GGGTAGTCCCGAAT': [[(11877, 1, 1)]],
#  'CCCTCATCCTGGAT': [[(14957, 0, 1), (14958, 0, 3), (14959, 0, 1)],
#   [(106729, 0, 1)]],
#  'ACCATGGTTTACAT': [[(10785, 1, 1)]],
#  'ATGACCCATCCACA': [[(126017, 1, 1)]],
#  'CACAGTTCTCACAG': [[(34846, 1, 6),
#    (34847, 1, 5),
#    (34848, 0, 1),
#    (34849, 1, 6),
#    (34850, 0, 6),
#    (34851, 1, 6),
#    (34852, 1, 3),
#    (34865, 1, 1),
#    (34866, 1, 1),
#    (34867, 1, 1)]],
#  'GATGAATCACTTGG': [[(72835, 0, 1), (72836, 0, 1)]],
#  'TGCCAAAGTGCGCA': [[(33747, 0, 1)],
#   [(89618, 0, 1), (89622, 0, 1), (89652, 0, 1)]],
#  'ATAGAGTCACCTAG': [[(55578, 1, 2), (55579, 0, 1)]],
#  'CGCATAAGTGATCA': [[(49981, 0, 1), (49982, 0, 1)], [(95321, 0, 1)]],
#  'GAGGCACAATCAAG': [[(349, 1, 1)]],
#  'GCTAGTGTAACATG': [[(66029, 0, 1)]],
#  'CCTTGCTCAGTACC': [[(95799, 1, 1)]],
#  'TGCCTCCACGTCTA': [[(45786, 0, 1)], [(96138, 2, 1)]],
#  'TAGTCGAGGACCGT': [[(46384, 1, 1), (46385, 1, 1)],
#   [(61066, 0, 1), (61067, 0, 1)]],
#  'GCCTAACACTCGTA': [[(27859, 0, 1),
#    (27865, 1, 1),
#    (27871, 1, 1),
#    (27879, 1, 1)],
#   [(44596, 1, 2),
#    (44624, 1, 1),
#    (44648, 1, 1),
#    (44661, 1, 1),
#    (44662, 0, 1),
#    (44672, 0, 1),
#    (44684, 0, 1),
#    (44706, 1, 1)],
#   [(91074, 0, 1)]],
#  'CCTCCAGTATCTTA': [[(74658, 1, 1)]],
#  'AGGTAAAGTCGACG': [[(77882, 1, 1),
#    (77883, 1, 1),
#    (77893, 1, 2),
#    (77898, 1, 3),
#    (77937, 1, 1),
#    (77946, 1, 1),
#    (77957, 1, 1),
#    (77962, 1, 1)],
#   [(106355, 1, 2)]],
#  'CGAACTGTGAGGCT': [[(440, 1, 1), (441, 0, 1)]],
#  'AGCACTCATGGACG': [[(16297, 0, 1)],
#   [(35729, 0, 1), (35730, 1, 1)],
#   [(92237, 0, 2)]],
#  'GAGCGATCCTCGTC': [[(28324, 1, 2)],
#   [(28536, 1, 2)],
#   [(49277, 1, 1), (49310, 1, 1), (49334, 1, 1), (49344, 1, 1)],
#   [(123398, 0, 1)]],
#  'GGATCTCATCGCGC': [[(67569, 0, 1)]],
#  'GGTCTATCGATCCA': [[(20072, 1, 2), (20073, 1, 2)]],
#  'GATACCCATTACTA': [[(2692, 1, 1),
#    (2693, 1, 1),
#    (2704, 1, 1),
#    (2705, 0, 1),
#    (2737, 1, 1),
#    (2739, 1, 1),
#    (2750, 1, 1),
#    (2752, 1, 3),
#    (2774, 1, 1),
#    (2824, 0, 1),
#    (2902, 1, 1),
#    (2903, 1, 1),
#    (2908, 0, 2)],
#   [(10679, 1, 1), (10680, 1, 1), (10681, 1, 1), (10682, 1, 1)]],
#  'TTCGCCGTTAGCAA': [[(42759, 1, 1)], [(121995, 1, 1)]],
#  'CAACGTAGTGCCGA': [[(61066, 0, 1), (61067, 0, 1)],
#   [(113027, 0, 1), (113028, 0, 1)]],
#  'TGTGCAAGTTGTGA': [[(60957, 1, 1)],
#   [(65794, 1, 3), (65808, 2, 1), (65809, 0, 1)],
#   [(82990, 0, 2)],
#   [(123436, 1, 1),
#    (123471, 1, 1),
#    (123473, 1, 1),
#    (123474, 1, 1),
#    (123529, 1, 1),
#    (123577, 1, 1),
#    (123601, 1, 1),
#    (123625, 1, 3),
#    (123628, 1, 1),
#    (123655, 0, 1),
#    (123656, 0, 1),
#    (123657, 0, 1),
#    (123666, 2, 2),
#    (123705, 1, 1),
#    (123723, 0, 1),
#    (123733, 0, 1),
#    (123767, 1, 2),
#    (123779, 1, 5),
#    (123782, 1, 4),
#    (123783, 0, 4),
#    (123802, 0, 1),
#    (123852, 1, 1),
#    (123855, 1, 3),
#    (123859, 1, 5),
#    (123877, 1, 1),
#    (123878, 0, 1),
#    (123939, 0, 1),
#    (123943, 1, 1),
#    (123944, 1, 2),
#    (124067, 0, 1),
#    (124068, 2, 1),
#    (124095, 0, 2),
#    (124109, 0, 1),
#    (124182, 1, 1),
#    (124186, 1, 1),
#    (124187, 0, 1)]],
#  'CCAAACTCTTCACT': [[(28133, 1, 1)]],
#  'AATGAGAGGCTATA': [[(78675, 0, 1)]],
#  'AGGAGCAGAGAGTG': [[(26738, 0, 1)]],
#  'TACGACAGGCTTTC': [[(13965, 0, 1)],
#   [(20071, 1, 1), (20104, 1, 1), (20107, 1, 1), (20131, 0, 1), (20165, 1, 1)],
#   [(68978, 1, 1)]],
#  'TTGGGTAGCCCGCT': [[(16423, 0, 1)]],
#  'CGAACTAGCTTGAA': [[(6299, 0, 3)],
#   [(33635, 1, 1), (33660, 1, 1)],
#   [(66953, 0, 1)],
#   [(94063, 1, 1)],
#   [(118842, 1, 1), (118845, 1, 1)]],
#  'CACCTCAGAGTACT': [[(30139, 2, 2), (30140, 1, 1), (30146, 0, 1)],
#   [(82086, 1, 1), (82108, 1, 1), (82109, 1, 2), (82111, 1, 1)]],
#  'TCGTCCGTTTATCA': [[(47298, 0, 1)]],
#  'GAAGGCTCCATCAG': [[(124378, 0, 1)]],
#  'ACCGATCAAGCAAT': [[(78191, 1, 1), (78249, 1, 2)],
#   [(78948, 1, 1), (78949, 1, 1)],
#   [(79016, 0, 1), (79017, 0, 1), (79117, 1, 1), (79119, 0, 1)],
#   [(79484, 0, 1)],
#   [(79655, 1, 1)]],
#  'AGGAGCCAACAGAT': [[(12392, 0, 1)]],
#  'TGGTTGTCCCTATT': [[(24108, 0, 1)]],
#  'GTCGATAGAGTTTG': [[(74098, 1, 1)]],
#  'AGATCCAGCTCGAG': [[(125582, 2, 1)]],
#  'AGCGAGGTTAAACG': [[(112303, 0, 1)]],
#  'GAACGGGTCCCATA': [[(9271, 1, 1), (9280, 0, 1), (9281, 0, 1), (9292, 1, 1)]],
#  'CGGGAATCTCTAGG': [[(46384, 1, 1), (46385, 0, 1)]],
#  'AGTGAATCTGTCAG': [[(75682, 1, 1)]],
#  'CTACGATCGACCTA': [[(122793, 1, 1)]],
#  'CTCCGTCAAGTCCT': [[(368, 0, 1)]],
#  'AGTACCCAACCGTT': [[(25535, 1, 1),
#    (25539, 2, 1),
#    (25540, 2, 1),
#    (25547, 1, 1),
#    (25548, 0, 1),
#    (25550, 0, 2),
#    (25553, 1, 2),
#    (25561, 1, 2),
#    (25564, 1, 1),
#    (25567, 0, 1),
#    (25570, 1, 1),
#    (25576, 1, 2),
#    (25590, 1, 2),
#    (25628, 1, 2),
#    (25631, 0, 2),
#    (25634, 1, 2),
#    (25635, 0, 1)],
#   [(51706, 1, 1),
#    (51707, 0, 1),
#    (51708, 0, 1),
#    (51716, 1, 1),
#    (51739, 1, 1),
#    (51770, 1, 1),
#    (51774, 0, 1),
#    (51775, 1, 1),
#    (51777, 1, 1),
#    (51789, 0, 1),
#    (51796, 1, 1),
#    (51840, 2, 2)],
#   [(121899, 1, 1), (121901, 0, 2)]],
#  'TACAGCCAGCCTCG': [[(109920, 0, 1)]],
#  'TACCAGTCTCCCGT': [[(105248, 1, 1)]],
#  'TCCGAATCAGCTCA': [[(49152, 0, 1)],
#   [(60731, 0, 1)],
#   [(109589, 1, 1),
#    (109623, 2, 1),
#    (109638, 0, 2),
#    (109694, 1, 1),
#    (109695, 1, 1),
#    (109696, 0, 1),
#    (109697, 1, 1),
#    (109716, 1, 3),
#    (109720, 1, 1),
#    (109724, 0, 1),
#    (109729, 1, 3),
#    (109733, 2, 1)]],
#  'GCAGTTCATTGTTA': [[(9220, 1, 1)], [(54123, 0, 1)]],
#  'CCTTATGTCAGAAT': [[(118206, 1, 1)]],
#  'GCCAATGTTTCTCT': [[(46583, 0, 1), (46584, 0, 1)],
#   [(85632, 0, 1)],
#   [(118182, 2, 2),
#    (118209, 1, 1),
#    (118216, 1, 1),
#    (118222, 1, 1),
#    (118229, 0, 5),
#    (118231, 0, 4),
#    (118239, 2, 1),
#    (118241, 2, 1),
#    (118246, 1, 2)]],
#  'TCCGCTAGAGAAAT': [[(48462, 1, 1),
#    (48463, 2, 1),
#    (48464, 1, 1),
#    (48475, 1, 2),
#    (48528, 1, 1),
#    (48529, 2, 1),
#    (48531, 1, 1),
#    (48546, 1, 1),
#    (48555, 1, 1),
#    (48556, 1, 1),
#    (48558, 1, 1),
#    (48563, 1, 1),
#    (48565, 1, 1),
#    (48568, 2, 1),
#    (48569, 1, 1),
#    (48570, 1, 1),
#    (48571, 1, 1)],
#   [(106355, 0, 1)]],
#  'GTGTACCATCGTTG': [[(106355, 0, 2)]],
#  'AAGTAGGTGCATTC': [[(7267, 1, 1)]],
#  'ACTCTTCATCGCCG': [[(29176, 0, 1)],
#   [(31222, 1, 2), (31258, 1, 1)],
#   [(106355, 0, 1)]],
#  'CTGAGTCAACCTTG': [[(14353, 1, 1)]],
#  'CAAAGACACGTGTT': [[(45117, 0, 1)], [(113541, 0, 1), (113545, 0, 1)]],
#  'TTCCGCTCCTGCTC': [[(44182, 0, 1)]],
# ...
#  'GATCCATCTTGGGT': [[(40399, 2, 1), (40400, 0, 2)]],
#  'ACACCACACCATAC': [[(6044, 0, 1)]],
#  'ATGGCTAGCATCTC': [[(95430, 1, 2),
#    (95433, 2, 2),
#    (95435, 1, 2),
#    (95437, 1, 1),
#    (95438, 0, 1),
#    (95440, 2, 3),
#    (95454, 1, 1),
#    (95472, 1, 1),
#    (95493, 0, 1),
#    (95509, 1, 2),
#    (95549, 0, 1)]],
#  'TTTCTGCATCAGGG': [[(96007, 1, 1), (96032, 1, 1)]],
#  'ATAGGAAGCAAGTT': [[(34056, 1, 1)]],
#  'CTCCCATCATCACG': [[(1615, 1, 1), (1617, 1, 1), (1618, 0, 1)],
#   [(63808, 1, 2)]],
#  'AGGAATTCTTAAAC': [[(5716, 0, 2), (5722, 1, 2), (5723, 1, 1)],
#   [(49867, 0, 1)]],
#  'CAGTTGTCAACTGC': [[(98302, 1, 1)]],
#  'CTGCTCTCCCTATT': [[(34842, 1, 2),
#    (34846, 0, 1),
#    (34847, 0, 1),
#    (34848, 0, 1),
#    (34849, 0, 1),
#    (34850, 0, 1),
#    (34851, 0, 1),
#    (34852, 0, 1),
#    (34854, 0, 1),
#    (34855, 0, 1),
#    (34856, 0, 1),
#    (34857, 0, 1),
#    (34858, 0, 1),
#    (34860, 0, 1),
#    (34861, 0, 1),
#    (34874, 1, 1),
#    (34876, 1, 3),
#    (34883, 1, 2),
#    (34896, 1, 1),
#    (34906, 1, 1)],
#   [(52017, 0, 1),
#    (52041, 1, 2),
#    (52077, 1, 2),
#    (52093, 1, 2),
#    (52096, 1, 5),
#    (52099, 1, 2),
#    (52110, 1, 2),
#    (52116, 1, 1)],
#   [(78667, 0, 1), (78678, 0, 1)]],
#  'CACCCTAGGACCGT': [[(66776, 1, 1)]],
#  'GCATACTCTTGGCA': [[(89338, 0, 1)]],
#  'CAAAGAGTGGTCCC': [[(28359, 0, 1)], [(100116, 1, 1)]],
#  'GCCAATAGATCGTA': [[(19415, 1, 1)],
#   [(94011, 1, 1),
#    (94013, 1, 1),
#    (94063, 1, 1),
#    (94074, 1, 1),
#    (94078, 1, 2),
#    (94158, 1, 1)]],
#  'ACTGCATCCCTCAC': [[(94048, 1, 1), (94063, 1, 1)],
#   [(94279, 1, 1), (94323, 0, 2)],
#   [(94407, 1, 1), (94429, 1, 1), (94431, 0, 1), (94447, 1, 1), (94448, 1, 1)],
#   [(94555, 1, 1),
#    (94579, 0, 1),
#    (94583, 1, 1),
#    (94603, 2, 1),
#    (94615, 1, 1),
#    (94616, 1, 1),
#    (94623, 1, 1),
#    (94648, 0, 1),
#    (94683, 1, 1),
#    (94692, 1, 2),
#    (94791, 0, 1),
#    (94807, 0, 1),
#    (94811, 0, 1),
#    (94821, 0, 1),
#    (94828, 1, 1),
#    (94850, 1, 1),
#    (94857, 0, 2),
#    (94867, 0, 1),
#    (94893, 0, 2),
#    (94917, 1, 1),
#    (94935, 0, 2),
#    (94944, 0, 1),
#    (94945, 1, 1)],
#   [(95101, 2, 1),
#    (95127, 1, 1),
#    (95140, 1, 1),
#    (95141, 0, 1),
#    (95145, 1, 4),
#    (95148, 1, 1),
#    (95156, 1, 1),
#    (95162, 2, 1),
#    (95171, 1, 1)]],
#  'TCCGCTAGTATCAG': [[(46385, 1, 1)]],
#  'TCCCGTCAGTCACT': [[(63731, 1, 1)], [(65818, 0, 1)]],
#  'CAAGAACACCTAAC': [[(89940, 2, 1)]],
#  'AAGGCGTCTCTCTA': [[(48916, 1, 1)]],
#  'GAGTAACACAGTTC': [[(53657, 1, 1)]],
#  'GGTCATCATTAGCC': [[(124413, 1, 1), (124419, 1, 1)]],
#  'CGACTACATCAAAG': [[(86117, 0, 1), (86118, 0, 2)]],
#  'GCATACGTGTAGCG': [[(20746, 1, 1), (20751, 1, 1)], [(31406, 1, 2)]],
#  'GGCAAGCAGTCGAG': [[(92286, 1, 1)]],
#  'GAGACGTCATTCCT': [[(19621, 1, 1), (19628, 1, 2)],
#   [(19777, 1, 1),
#    (19785, 1, 2),
#    (19786, 2, 2),
#    (19791, 1, 1),
#    (19829, 0, 1),
#    (19927, 1, 1),
#    (19928, 1, 1),
#    (19931, 2, 2),
#    (19937, 1, 2),
#    (19939, 1, 1),
#    (19947, 1, 3),
#    (19948, 1, 3),
#    (19949, 1, 3),
#    (19953, 1, 1),
#    (19956, 1, 2)]],
#  'CGCATAAGACTACA': [[(40693, 1, 1), (40702, 1, 1)]],
#  'GAACGGTCAATATC': [[(58566, 1, 2)], [(122237, 1, 1), (122238, 1, 2)]],
#  'CGACTATCATTACA': [[(93381, 0, 1)]],
#  'GTTGCAGTTTCGTG': [[(77957, 0, 1)]],
#  'TCACAGTCCTGAGT': [[(9151, 1, 1)],
#   [(9783, 1, 1), (9822, 1, 1), (9834, 1, 1), (9835, 1, 1), (9839, 1, 1)],
#   [(10211, 0, 1),
#    (10310, 1, 2),
#    (10314, 1, 1),
#    (10327, 1, 1),
#    (10329, 1, 1),
#    (10399, 1, 1),
#    (10452, 1, 1),
#    (10457, 1, 1)]],
#  'CTGATGTCCTTGCC': [[(33747, 0, 1)], [(71299, 0, 1)], [(72422, 1, 1)]],
#  'GGCAAGCATCTCTT': [[(45888, 0, 1),
#    (45891, 1, 1),
#    (45892, 0, 1),
#    (45893, 0, 1),
#    (45896, 0, 2),
#    (45905, 2, 1),
#    (45906, 0, 1),
#    (45907, 0, 2),
#    (45908, 0, 2),
#    (45915, 0, 1),
#    (45916, 2, 1),
#    (45917, 0, 1),
#    (45930, 2, 1),
#    (45931, 1, 1),
#    (45933, 2, 1),
#    (45934, 1, 1),
#    (45940, 2, 1)]],
#  'GGAGCAGTTCTTGG': [[(52189, 0, 2)]],
#  'GCTACATCTACACG': [[(4710, 2, 1)],
#   [(15959, 1, 1)],
#   [(16184, 1, 1), (16186, 1, 1), (16187, 1, 1), (16188, 1, 1)],
#   [(40136, 1, 1)],
#   [(95893, 0, 1), (95894, 0, 1), (95895, 1, 1)],
#   [(109270, 1, 2)]],
#  'GCCAATTCGATATT': [[(51596, 0, 1)]],
#  'GAAGGCAGTCGAAT': [[(119271, 0, 1),
#    (119322, 0, 1),
#    (119323, 0, 1),
#    (119407, 1, 1),
#    (119511, 1, 2),
#    (119533, 1, 1)]],
#  'AAAGCATCCGCAAT': [[(119111, 1, 1),
#    (119129, 0, 2),
#    (119130, 1, 1),
#    (119131, 1, 1),
#    (119147, 1, 1),
#    (119170, 1, 1),
#    (119191, 1, 1)]],
#  'ATCGGTGTGTAGTA': [[(37747, 0, 1)],
#   [(62947, 0, 1), (62960, 1, 1), (62967, 1, 5), (62968, 1, 4)],
#   [(70396, 0, 2)],
#   [(106355, 1, 2)]],
#  'CAAGAATCATTCCT': [[(42910, 1, 2),
#    (42912, 1, 2),
#    (42913, 1, 1),
#    (42914, 1, 1)]],
#  'TCGCAAAGCGGTTG': [[(122613, 1, 1)]],
#  'TCGCAAAGAGGAGT': [[(91570, 2, 2)]],
#  'AGTGCTAGTGTTCC': [[(65601, 0, 1)], [(106049, 1, 1), (106084, 0, 1)]],
#  'TTCTCAAGCAAATC': [[(97129, 1, 1)]],
#  'TATGCGCAACTGAA': [[(46089, 1, 1)]],
#  'GGGACAGTGTCACT': [[(13559, 1, 1),
#    (13588, 1, 1),
#    (13594, 1, 1),
#    (13619, 0, 1),
#    (13620, 1, 1),
#    (13646, 1, 1)]],
#  'TCCGCTCATTCATA': [[(61065, 0, 2), (61066, 0, 2), (61067, 0, 2)],
#   [(125594, 1, 1)]],
#  'ATACGCGTCTTCAG': [[(62253, 1, 1)],
#   [(78675, 1, 1)],
#   [(105286, 2, 1)],
#   [(105446, 0, 1), (105447, 1, 1)]],
#  'CAGAAAAGTCTTCG': [[(72944, 0, 1)]],
#  'CCGAATGTTCGGGA': [[(5184, 0, 5)]],
#  'GTACCACAACAATG': [[(91074, 0, 2)]],
#  'TGTCGATCGATCCA': [[(1406, 1, 1), (1413, 0, 3), (1415, 0, 1)],
#   [(116499, 2, 1),
#    (116500, 2, 1),
#    (116502, 0, 1),
#    (116503, 1, 1),
#    (116504, 0, 1),
#    (116506, 0, 4),
#    (116512, 0, 3),
#    (116514, 1, 2),
#    (116517, 0, 4),
#    (116518, 2, 4),
#    (116519, 1, 3),
#    (116523, 0, 1),
#    (116524, 0, 1),
#    (116534, 1, 1),
#    (116535, 1, 2),
#    (116540, 0, 1),
#    (116548, 1, 2),
#    (116555, 1, 2),
#    (116556, 1, 1),
#    (116565, 1, 2),
#    (116566, 1, 1),
#    (116570, 1, 3),
#    (116571, 1, 1),
#    (116578, 1, 2),
#    (116579, 1, 2),
#    (116592, 0, 2),
#    (116593, 0, 2),
#    (116610, 1, 1),
#    (116612, 1, 1),
#    (116617, 0, 1),
#    (116618, 1, 1),
#    (116622, 1, 1),
#    (116631, 1, 1),
#    (116638, 2, 2),
#    (116649, 0, 4),
#    (116655, 1, 2),
#    (116657, 0, 2),
#    (116674, 2, 1),
#    (116678, 2, 2),
#    (116693, 1, 1),
#    (116694, 2, 1),
#    (116696, 1, 2),
#    (116697, 0, 1),
#    (116700, 0, 1),
#    (116705, 0, 1),
#    (116723, 1, 1),
#    (116724, 1, 1),
#    (116725, 1, 1),
#    (116727, 1, 2),
#    (116742, 1, 1)],
#   [(125114, 0, 1)]],
#  'CTGAGTCAATCTAT': [[(115055, 1, 1),
#    (115071, 0, 1),
#    (115097, 0, 2),
#    (115109, 0, 1),
#    (115137, 1, 1)]],
#  'GGAAATAGCTACAA': [[(91260, 1, 1)],
#   [(106355, 0, 1)],
#   [(113556, 0, 1),
#    (113565, 1, 1),
#    (113577, 0, 3),
#    (113579, 1, 1),
#    (113586, 1, 1),
#    (113598, 2, 1),
#    (113602, 1, 1),
#    (113609, 2, 1),
#    (113612, 1, 1),
#    (113613, 1, 2),
#    (113642, 1, 1),
#    (113645, 1, 1),
#    (113646, 1, 1),
#    (113648, 1, 1),
#    (113649, 1, 1)]],
#  'TCAGCAGTGTCACT': [[(82451, 1, 1),
#    (82472, 1, 1),
#    (82473, 1, 1),
#    (82488, 1, 2),
#    (82523, 1, 1)]],
#  'AGCACTGTACTTAT': [[(115208, 1, 1),
#    (115209, 1, 1),
#    (115210, 1, 1),
#    (115217, 0, 1),
#    (115228, 1, 2),
#    (115291, 0, 2),
#    (115300, 1, 1),
#    (115315, 0, 1),
#    (115370, 0, 1),
#    (115430, 1, 1),
#    (115456, 1, 3),
#    (115457, 1, 4),
#    (115460, 1, 1),
#    (115461, 1, 1),
#    (115465, 1, 1),
#    (115480, 1, 1),
#    (115512, 0, 1),
#    (115528, 0, 2),
#    (115538, 0, 2),
#    (115540, 1, 2),
#    (115544, 0, 1),
#    (115545, 0, 1),
#    (115549, 2, 1),
#    (115563, 0, 1),
#    (115583, 2, 2),
#    (115584, 1, 2),
#    (115585, 2, 2),
#    (115725, 1, 1),
#    (115733, 1, 1),
#    (115745, 1, 1),
#    (115747, 1, 1),
#    (115757, 1, 1)]],
#  'AGCAAAGTGCGTAG': [[(37269, 0, 1)]],
#  'CCAAACCAGGTCCC': [[(74977, 0, 1), (75036, 1, 2), (75072, 1, 1)]],
#  'GACTGTTCTTGGGT': [[(106355, 0, 1)]],
#  'CTATTCTCATCACG': [[(13478, 0, 1), (13479, 0, 1)], [(102698, 1, 1)]],
#  'TCCGCTGTGGTCCC': [[(2891, 1, 1),
#    (2930, 1, 2),
#    (2932, 1, 1),
#    (2969, 0, 1),
#    (3035, 1, 1),
#    (3038, 1, 2)],
#   [(21543, 1, 1), (21551, 1, 1), (21579, 1, 1), (21634, 1, 1)],
#   [(56223, 0, 1)],
#   [(62620, 0, 2), (62622, 2, 1)],
#   [(99986, 0, 1)],
#   [(106355, 0, 2)]],
#  'TGGGAGCACTTGCA': [[(44079, 0, 1)]],
#  'GCTGTAAGGCTCAG': [[(39161, 1, 1)]],
#  'CTCCCACAACTAGA': [[(113, 0, 1)]],
#  'CTAGCAGTTTGTGC': [[(32852, 1, 1), (32853, 1, 1)],
#   [(33049, 1, 1),
#    (33065, 1, 1),
#    (33088, 1, 1),
#    (33089, 1, 1),
#    (33128, 1, 1),
#    (33133, 0, 1),
#    (33187, 1, 1),
#    (33188, 1, 2),
#    (33228, 1, 1)],
#   [(33330, 1, 2), (33335, 1, 1)]],
#  'TGAAGAAGTTACAG': [[(10238, 0, 1),
#    (10265, 1, 1),
#    (10266, 1, 1),
#    (10276, 1, 2),
#    (10282, 1, 1),
#    (10283, 0, 1),
#    (10286, 0, 1),
#    (10293, 2, 2),
#    (10313, 2, 2),
#    (10314, 2, 1),
#    (10327, 2, 1),
#    (10330, 1, 1),
#    (10336, 1, 1),
#    (10392, 1, 1)]],
#  'AGGAATCACGCCGT': [[(96373, 2, 1)]],
#  'TGAACCTCGGATGG': [[(104630, 2, 1)]],
#  'GGTAAAGTGATGGC': [[(125408, 1, 1)]],
#  'CCATAGTCGACTAC': [[(61304, 1, 1)]],
#  'ACCACATCCTCAAG': [[(89483, 0, 1)]],
#  'GAAACAGTTGTCGT': [[(91839, 1, 1),
#    (91840, 1, 1),
#    (91879, 1, 1),
#    (91880, 0, 1),
#    (91882, 1, 1),
#    (91883, 1, 1),
#    (91937, 1, 1),
#    (91987, 1, 2),
#    (92085, 1, 1),
#    (92089, 0, 1),
#    (92092, 0, 1),
#    (92124, 0, 2),
#    (92126, 0, 1),
#    (92134, 0, 1),
#    (92211, 1, 1),
#    (92281, 0, 1),
#    (92294, 1, 1),
#    (92337, 1, 1),
#    (92338, 1, 1),
#    (92342, 1, 1),
#    (92345, 1, 1),
#    (92352, 1, 2),
#    (92355, 1, 1),
#    (92359, 1, 1)]],
#  'AGGCGATCCTACGA': [[(6042, 1, 1), (6107, 1, 1), (6108, 0, 1)]],
#  'AAAGGTGTTAATCT': [[(51809, 0, 1),
#    (51815, 0, 1),
#    (51822, 0, 4),
#    (51834, 2, 1),
#    (51943, 1, 1),
#    (51994, 0, 1)],
#   [(52135, 1, 1), (52164, 1, 1), (52179, 0, 1), (52189, 0, 1), (52199, 0, 1)],
#   [(52597, 1, 1),
#    (52615, 1, 1),
#    (52620, 1, 1),
#    (52692, 1, 2),
#    (52703, 1, 2),
#    (52714, 1, 1),
#    (52717, 1, 2),
#    (52729, 1, 2),
#    (52731, 1, 1),
#    (52733, 1, 1),
#    (52742, 1, 1),
#    (52750, 1, 1),
#    (52754, 1, 2),
#    (52768, 1, 4),
#    (52769, 0, 7),
#    (52772, 0, 1),
#    (52776, 1, 1),
#    (52784, 0, 1),
#    (52787, 1, 2),
#    (52798, 1, 1)],
#   [(52898, 1, 3),
#    (52899, 0, 1),
#    (52908, 1, 2),
#    (52909, 0, 2),
#    (52940, 1, 1),
#    (52952, 2, 1),
#    (52981, 0, 1),
#    (53020, 0, 2),
#    (53031, 1, 1),
#    (53037, 1, 1),
#    (53086, 1, 2),
#    (53134, 1, 1),
#    (53154, 0, 1),
#    (53155, 0, 1)],
#   [(53236, 1, 1), (53304, 1, 1)]],
#  'CCCTCACAACACCT': [[(23128, 0, 1)]],
#  'ACTGCAAGCCGTTT': [[(39889, 1, 2),
#    (39906, 1, 2),
#    (39911, 1, 1),
#    (39915, 2, 3),
#    (40044, 1, 1),
#    (40049, 1, 2),
#    (40056, 1, 1),
#    (40057, 1, 1),
#    (40206, 1, 1),
#    (40225, 1, 1),
#    (40230, 1, 2),
#    (40232, 1, 1),
#    (40248, 1, 2),
#    (40269, 0, 1),
#    (40275, 0, 1),
#    (40313, 1, 1),
#    (40315, 1, 2),
#    (40317, 2, 2),
#    (40319, 0, 1),
#    (40344, 1, 1)]],
#  'CTAGCACACGCTCG': [[(66688, 0, 1), (66690, 0, 1)]],
#  'TTGCAGAGTACCGG': [[(97178, 1, 1)]],
#  'TGTAGCTCGTGGGA': [[(73711, 1, 1)]],
#  'GTAGCTAGTCGCAG': [[(54475, 1, 1), (54476, 1, 1)]],
#  'TGTTTCTCTTGCTT': [[(57254, 0, 1)], [(83941, 0, 1)]],
#  'TTCTCAAGTGGCGT': [[(58440, 1, 1)]],
#  'ACGAAACAGAGATT': [[(79060, 2, 1),
#    (79092, 1, 1),
#    (79094, 1, 2),
#    (79147, 1, 1)],
#   [(79489, 1, 1)]],
#  'AATAGGAGAGCTAT': [[(36674, 1, 1)], [(69171, 1, 1)]],
#  'GAAGGCGTGAGTCG': [[(60091, 1, 1), (60092, 0, 1)]],
#  'TCGCCTTCGTTAAT': [[(27329, 1, 1),
#    (27346, 1, 1),
#    (27423, 1, 1),
#    (27445, 0, 1)],
#   [(80960, 0, 1)]],
#  'CCTGTCCAGCAGTG': [[(34857, 1, 1), (34858, 0, 1)]],
#  'CTACAGCAGACTCT': [[(54470, 0, 2),
#    (54471, 0, 4),
#    (54472, 0, 4),
#    (54473, 1, 4),
#    (54474, 0, 4),
#    (54475, 1, 3),
#    (54476, 1, 1),
#    (54477, 1, 2),
#    (54478, 1, 1)]],
#  'CAAGGGTCGTCCCT': [[(27043, 1, 1)]],
#  'CCTAGATCTAGTTA': [[(33176, 0, 1), (33177, 0, 1)]],
#  'TCATGGTCTATCCT': [[(2387, 1, 1)],
#   [(56947, 0, 1), (56955, 1, 1), (56959, 1, 1)]],
#  'TCGTAGAGTTCCGT': [[(22736, 0, 1)],
#   [(53735, 2, 1),
#    (53738, 1, 1),
#    (53741, 1, 2),
#    (53742, 1, 2),
#    (53759, 1, 2),
#    (53760, 1, 1),
#    (53762, 1, 2),
#    (53766, 1, 1),
#    (53767, 1, 1),
#    (53777, 1, 1),
#    (53780, 1, 1),
#    (53793, 2, 1),
#    (53794, 1, 1),
#    (53795, 1, 2),
#    (53800, 1, 1),
#    (53809, 1, 2),
#    (53821, 1, 1),
#    (53846, 0, 1),
#    (53847, 0, 1),
#    (53849, 0, 2),
#    (53851, 0, 1),
#    (53852, 0, 2),
#    (53853, 0, 2),
#    (53858, 0, 1),
#    (53884, 0, 1),
#    (53886, 0, 1),
#    (53890, 0, 2),
#    (53894, 0, 3),
#    (53895, 1, 1),
#    (53977, 1, 3),
#    (53979, 0, 1),
#    (53984, 1, 1),
#    (54029, 0, 2),
#    (54069, 1, 1),
#    (54073, 1, 2),
#    (54074, 1, 2),
#    (54081, 2, 1),
#    (54100, 1, 1),
#    (54150, 1, 2),
#    (54157, 2, 1),
#    (54165, 1, 1),
#    (54172, 1, 1),
#    (54182, 1, 1),
#    (54185, 1, 1),
#    (54193, 1, 3),
#    (54197, 1, 2),
#    (54214, 1, 1),
#    (54215, 1, 1),
#    (54216, 1, 1),
#    (54228, 0, 1),
#    (54230, 0, 2)],
#   [(81468, 1, 2)]],
#  'AGTGCTTCCGAGTT': [[(23539, 1, 2), (23540, 2, 2)], [(56285, 1, 1)]],
#  'CCCTCAAGTGATCA': [[(64858, 1, 1)]],
#  'CTCCTGTCGACTCA': [[(15720, 2, 3), (15803, 1, 1), (15804, 0, 1)],
#   [(15909, 0, 8)],
#   [(16063, 2, 1),
#    (16104, 1, 1),
#    (16115, 1, 1),
#    (16116, 1, 1),
#    (16117, 0, 1),
#    (16143, 1, 1),
#    (16152, 1, 1),
#    (16154, 1, 1),
#    (16160, 1, 1),
#    (16172, 1, 1),
#    (16178, 1, 1),
#    (16182, 0, 1),
#    (16183, 1, 1),
#    (16185, 2, 2),
#    (16186, 2, 1),
#    (16187, 2, 2),
#    (16188, 1, 2),
#    (16202, 0, 1),
#    (16204, 2, 1),
#    (16205, 0, 3)],
#   [(16298, 1, 1), (16306, 1, 1), (16311, 1, 1)],
#   [(16555, 0, 1),
#    (16582, 0, 1),
#    (16595, 1, 2),
#    (16601, 1, 1),
#    (16663, 1, 1),
#    (16676, 1, 3)]],
#  'AACTCGCAGTGTCT': [[(64332, 0, 1)]],
#  'CACTGAGTTTGGTC': [[(103893, 1, 1)]],
#  'GTGACTAGCGACGT': [[(52215, 0, 1)], [(120144, 1, 1)]],
#  'AGTAGACACATGAA': [[(1815, 1, 1)],
#   [(6103, 0, 1)],
#   [(79553, 1, 1),
#    (79565, 1, 1),
#    (79576, 1, 4),
#    (79587, 1, 1),
#    (79591, 1, 1),
#    (79593, 1, 5),
#    (79606, 1, 4),
#    (79607, 2, 5),
#    (79623, 1, 1)]],
#  'TAGCGTTCCTTATC': [[(54077, 1, 1)],
#   [(54188, 2, 2), (54195, 1, 1), (54199, 0, 1), (54203, 1, 1)],
#   [(54366, 1, 1)]],
#  'TCGTCCCACGTCTA': [[(33303, 1, 1),
#    (33304, 0, 3),
#    (33330, 1, 1),
#    (33356, 1, 1),
#    (33370, 1, 1),
#    (33385, 1, 1),
#    (33408, 1, 1),
#    (33573, 1, 1),
#    (33578, 1, 4),
#    (33580, 1, 2),
#    (33605, 1, 1),
#    (33623, 1, 1),
#    (33625, 1, 3),
#    (33627, 1, 1),
#    (33635, 1, 1),
#    (33637, 1, 1),
#    (33638, 1, 1),
#    (33641, 2, 1),
#    (33647, 1, 1),
#    (33668, 1, 2)],
#   [(35778, 1, 1)]],
#  'TCATTCCATCGTGT': [[(55122, 1, 2), (55123, 0, 2)]],
#  'GACACTGTGAGATT': [[(81709, 1, 2), (81735, 1, 1)]],
#  'TAACGCCAGACTTC': [[(119364, 1, 1),
#    (119390, 1, 2),
#    (119391, 1, 1),
#    (119445, 1, 1),
#    (119450, 1, 1)]],
#  'TCCGTCAGTGCTGG': [[(76651, 1, 1)], [(92488, 1, 2)]],
#  'GCTAACCATTTCCT': [[(118793, 1, 3),
#    (118795, 1, 1),
#    (118822, 1, 1),
#    (118838, 1, 1),
#    (118860, 0, 1),
#    (118861, 1, 1),
#    (118868, 0, 1),
#    (118869, 0, 1),
#    (118873, 1, 1),
#    (118926, 1, 3),
#    (118927, 1, 1),
#    (118935, 1, 1),
#    (118944, 1, 3),
#    (118949, 1, 1),
#    (118967, 1, 1),
#    (119001, 0, 2)]],
#  'ACTTTCCATAACCC': [[(28491, 0, 1)]],
#  'TTGGGTTCTTCACT': [[(39185, 0, 1)],
#   [(39470, 0, 1)],
#   [(52331, 1, 1), (52333, 1, 1)]],
#  'ATTGCGGTTAGGCG': [[(30221, 1, 1)],
#   [(50835, 1, 1)],
#   [(80545, 1, 1)],
#   [(113760, 0, 1)]],
#  'CTCTCGCAGCATTC': [[(102334, 0, 1)]],
#  'ACCACAAGAGGTAG': [[(23612, 1, 1)]],
#  'GATAGAAGAGAGTG': [[(25080, 0, 4), (25172, 1, 1)], [(120996, 0, 1)]],
#  'TTACGGCACTCCGG': [[(96428, 1, 1),
#    (96498, 2, 1),
#    (96519, 2, 1),
#    (96523, 1, 1),
#    (96548, 0, 1),
#    (96564, 0, 1),
#    (96719, 1, 1),
#    (96721, 1, 1)],
#   [(103559, 0, 1)]],
#  'TCTATCCAGCCTAT': [[(17006, 1, 1)]],
#  'TGCCAAAGGGTCCA': [[(125443, 1, 2)]],
#  'GAATCCCAGCTGAG': [[(99371, 2, 1),
#    (99372, 1, 1),
#    (99375, 0, 2),
#    (99383, 1, 1)]],
#  'GCTCTCTCCTTATC': [[(114139, 0, 1)]],
#  'TGTGTGGTGGATTA': [[(26144, 1, 1), (26145, 1, 1)]],
#  'CCCGTTGTCTGGGA': [[(53031, 1, 1), (53117, 1, 1)],
#   [(110015, 1, 2), (110016, 0, 1), (110018, 1, 1)]],
#  'ACTCCCAGCTGCAG': [[(46384, 1, 1)]],
#  'TCTGTTAGAATTGC': [[(40025, 2, 1), (40044, 1, 1)]],
#  'TCATTCCAGGTGGT': [[(45980, 1, 1),
#    (46176, 1, 2),
#    (46179, 1, 1),
#    (46191, 0, 1),
#    (46227, 1, 1),
#    (46229, 1, 1)]],
#  'GAGATAAGCAGCGT': [[(63935, 0, 1)]],
#  ...}

# %%
count = 0
out_fn = open("./tenx_hairs_000000F_snps_pbcoord_3.hairs", 'w')
pbar = ProgressBar(len(barcode_hairs))
for barcode, blocks in barcode_hairs.iteritems():
    pbar.animate()
    count += 1
    #largestblock = [i for i in blocks if len(i) == max([len(i) for i in blocks])][0]
    #ix = 0
    #i = largestblock
    for ix,i in enumerate(blocks):
        block_variants = [a[0] for a in i]
        block_genotypes = [str(a[1]) for a in i]
        if len(block_genotypes) < 2:
            continue
        blocks_arr = []
        name = barcode + "/" + str(ix)
        for k, g in groupby(enumerate(block_variants), lambda (z,x):z-x):
            blocks_arr.append(map(itemgetter(1), g))
        outstr = '\t'.join([str(v) for v in [len(blocks), name]]) + '\t'
        for c in blocks_arr:
            outstr += str(c[0]) + '\t'
            outstr += ''.join([block_genotypes[block_variants.index(n)] for n in c]) + '\t'
        outstr += ''.join(["+" for n in block_genotypes])
        #print outstr
        out_fn.write(outstr + '\n')
out_fn.close()

# %%
nx.write_gexf(barcodegraph, "/hpc/users/neffr01/barcodegraph_tenx_snps_indels_000000F_30k.gexf")

# %%
barcodegraph.edge['000000F:4415338_1']
# Out:
# {'000000F:4411090_1': {'weight': 2},
#  '000000F:4413303_1': {'weight': 3},
#  '000000F:4415276_0': {'weight': 2},
#  '000000F:4415354_1': {'weight': 10}}

# %% [markdown]
# # Interblock definitions

# %%
excelfile = '/hpc/users/neffr01/jason_new/hapcut_outputs/hg002_re_000000F/hapcut_with_indels/hg002_000000F.indels.interblock_stats.tsv'
interblock_stats = pd.read_csv(excelfile, sep='\t')

# %%
def n50(arr):
    calcarr = [list(np.ones(x).astype(int)*x) for x in arr]
    calcarr = [item for sublist in calcarr for item in sublist]
    return np.median(calcarr)
